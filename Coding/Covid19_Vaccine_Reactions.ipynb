# %% [markdown]
# # Covid19 Vaccines + Reactions

# %% [markdown]
# ### Tables were generated/loaded:

# %%
import os
import pandas as pd
import datetime as dt
import seaborn as sns
import pyodbc
import psycopg2
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
from sqlalchemy.orm import Session
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.automap import automap_base

# %%
import csv
import pandas as pd
import dask.dataframe as dd
import os
import datetime
import operator
import pylab
import glob
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress 
from functools import reduce
import seaborn as sns 
# %matplotlib inline
from scipy import stats

# %%
SympRaw_data_path = '~/DataClass/project2/Data/2021VAERSSYMPTOMS.csv'
SympRaw_data = pd.read_csv(SympRaw_data_path, encoding="ISO-8859-1")
SympRaw_data.head(10)
# Out:
#    VAERS_ID                            SYMPTOM1  SYMPTOMVERSION1  \
# 0    916710                        Appendicitis             23.1
# 1    916741                              Chills             23.1
# 2    916741                             Myalgia             23.1
# 3    916742               Anaphylactic reaction             23.1
# 4    916742                      Intensive care             23.1
# 5    916746               Anaphylactic reaction             23.1
# 6    916746   Immediate post-injection reaction             23.1
# 7    916772                    Feeling abnormal             23.1
# 8    916790  Blood pressure diastolic increased             23.1
# 9    916790                   Electrocardiogram             23.1
#
#                                SYMPTOM2  SYMPTOMVERSION2  \
# 0  Band neutrophil percentage increased             23.1
# 1        Complex regional pain syndrome             23.1
# 2                     Pain in extremity             23.1
# ...

# %%
df = SympRaw_data.copy()
df
# Out:
#       VAERS_ID                                  SYMPTOM1  SYMPTOMVERSION1  \
# 0       916710                              Appendicitis             23.1
# 1       916741                                    Chills             23.1
# 2       916741                                   Myalgia             23.1
# 3       916742                     Anaphylactic reaction             23.1
# 4       916742                            Intensive care             23.1
# ...        ...                                       ...              ...
# 4707    983721                                     Death             23.1
# 4708    983766                        Blood pH decreased             23.1
# 4709    983766  International normalised ratio increased             23.1
# 4710    983919                                     Death             23.1
# 4711    985205                                     Death             23.1
#
#                                                SYMPTOM2  SYMPTOMVERSION2  \
# ...

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
display(df.head(10))
display(df.tail(10))
# Out:
#    VAERS_ID                            SYMPTOM1  SYMPTOMVERSION1  \
# 0    916710                        Appendicitis             23.1
# 1    916741                              Chills             23.1
# 2    916741                             Myalgia             23.1
# 3    916742               Anaphylactic reaction             23.1
# 4    916742                      Intensive care             23.1
# 5    916746               Anaphylactic reaction             23.1
# 6    916746   Immediate post-injection reaction             23.1
# 7    916772                    Feeling abnormal             23.1
# 8    916790  Blood pressure diastolic increased             23.1
# 9    916790                   Electrocardiogram             23.1
#
#                                SYMPTOM2  SYMPTOMVERSION2  \
# 0  Band neutrophil percentage increased             23.1
# 1        Complex regional pain syndrome             23.1
# 2                     Pain in extremity             23.1
# ...

# %%
SympRaw_data.columns.values
# Out:
# array(['VAERS_ID', 'SYMPTOM1', 'SYMPTOMVERSION1', 'SYMPTOM2',
#        'SYMPTOMVERSION2', 'SYMPTOM3', 'SYMPTOMVERSION3', 'SYMPTOM4',
#        'SYMPTOMVERSION4', 'SYMPTOM5', 'SYMPTOMVERSION5'], dtype=object)

# %%
SympRaw_Columns = list(SympRaw_data.columns)
SympRaw_Columns
# Out:
# ['VAERS_ID',
#  'SYMPTOM1',
#  'SYMPTOMVERSION1',
#  'SYMPTOM2',
#  'SYMPTOMVERSION2',
#  'SYMPTOM3',
#  'SYMPTOMVERSION3',
#  'SYMPTOM4',
#  'SYMPTOMVERSION4',
#  'SYMPTOM5',
#  'SYMPTOMVERSION5']

# %%
SympRaw_data.dtypes
# Out:
# VAERS_ID             int64
# SYMPTOM1            object
# SYMPTOMVERSION1    float64
# SYMPTOM2            object
# SYMPTOMVERSION2    float64
# SYMPTOM3            object
# SYMPTOMVERSION3    float64
# SYMPTOM4            object
# SYMPTOMVERSION4    float64
# SYMPTOM5            object
# SYMPTOMVERSION5    float64
# dtype: object

# %%
Countyraw_data_path = '~/DataClass/project2/Data/country_vaccinations.csv'
Countyraw_data = pd.read_csv(Countyraw_data_path, encoding="ISO-8859-1")
Countyraw_data.head(10)
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Algeria      DZA  2021-01-29                 0.0                NaN
# 1  Algeria      DZA  2021-01-30                30.0                NaN
# 2  Andorra      AND  2021-01-25               576.0              576.0
# 3  Andorra      AND  2021-01-26                 NaN                NaN
# 4  Andorra      AND  2021-01-27                 NaN                NaN
# 5  Andorra      AND  2021-01-28                 NaN                NaN
# 6  Andorra      AND  2021-01-29                 NaN                NaN
# 7  Andorra      AND  2021-01-30                 NaN                NaN
# 8  Andorra      AND  2021-01-31                 NaN                NaN
# 9  Andorra      AND  2021-02-01              1036.0             1036.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# ...

# %%
df = Countyraw_data.copy()
df
# Out:
#                    country iso_code        date  total_vaccinations  \
# 0                  Algeria      DZA  2021-01-29                 0.0
# 1                  Algeria      DZA  2021-01-30                30.0
# 2                  Andorra      AND  2021-01-25               576.0
# 3                  Andorra      AND  2021-01-26                 NaN
# 4                  Andorra      AND  2021-01-27                 NaN
# 5                  Andorra      AND  2021-01-28                 NaN
# 6                  Andorra      AND  2021-01-29                 NaN
# 7                  Andorra      AND  2021-01-30                 NaN
# 8                  Andorra      AND  2021-01-31                 NaN
# 9                  Andorra      AND  2021-02-01              1036.0
# 10               Argentina      ARG  2020-12-29               700.0
# 11               Argentina      ARG  2020-12-30                 NaN
# 12               Argentina      ARG  2020-12-31             32013.0
# ...

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
display(df.head(10))
display(df.tail(10))
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Algeria      DZA  2021-01-29                 0.0                NaN
# 1  Algeria      DZA  2021-01-30                30.0                NaN
# 2  Andorra      AND  2021-01-25               576.0              576.0
# 3  Andorra      AND  2021-01-26                 NaN                NaN
# 4  Andorra      AND  2021-01-27                 NaN                NaN
# 5  Andorra      AND  2021-01-28                 NaN                NaN
# 6  Andorra      AND  2021-01-29                 NaN                NaN
# 7  Andorra      AND  2021-01-30                 NaN                NaN
# 8  Andorra      AND  2021-01-31                 NaN                NaN
# 9  Andorra      AND  2021-02-01              1036.0             1036.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# ...

# %%
Countyraw_data.columns.values
# Out:
# array(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred',
#        'daily_vaccinations_per_million', 'vaccines', 'source_name',
#        'source_website'], dtype=object)

# %%
Countyraw_Columns = list(Countyraw_data.columns)
Countyraw_Columns
# Out:
# ['country',
#  'iso_code',
#  'date',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'daily_vaccinations_raw',
#  'daily_vaccinations',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'daily_vaccinations_per_million',
#  'vaccines',
#  'source_name',
#  'source_website']

# %%
Countyraw_data.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
Worldraw_data_path = '~/DataClass/project2/Data/WorldWideData.csv'
Worldraw_data = dd.read_csv(Worldraw_data_path, encoding="ISO-8859-1")
display(Worldraw_data.head(10))
display(Worldraw_data.tail(10))
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          1.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          1.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          1.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          2.0        1.0
# 9      AFG      Asia  Afghanistan  2020-03-04          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# ...

# %%
Worldraw_data.columns.values
# Out:
# array(['iso_code', 'continent', 'location', 'date', 'total_cases',
#        'new_cases', 'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate',
#        'icu_patients', 'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units',
#        'total_vaccinations', 'people_vaccinated',
#        'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
Worldraw_data.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# total_cases                              float64
# new_cases                                float64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# icu_patients_per_million                 float64
# ...

# %%
ExtractedColumns = Worldraw_data[['iso_code',
 'continent',
 'location',
 'date',
 'total_cases',
 'new_cases' , 
 'total_deaths',
 'new_deaths',
 'total_tests',
 'positive_rate',
 'total_vaccinations',
 'people_vaccinated',
 'people_fully_vaccinated',
 'new_vaccinations',
 'population',
 'median_age',
 'aged_65_older',
 'aged_70_older'
]]
display(ExtractedColumns.head(10))
display(ExtractedColumns.tail(10))
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          1.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          1.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          1.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          2.0        1.0
# 9      AFG      Asia  Afghanistan  2020-03-04          4.0        2.0
#
#    total_deaths  new_deaths  total_tests  positive_rate  total_vaccinations  \
# 0           NaN         NaN          NaN            NaN                 NaN
# ...

# %%
engine = create_engine('sqlite:///CVRData.db', echo=False)
sqlite_connection = engine.connect()

# %%
sqlite_CVRData = "CVRData"
ExtractedColumns.to_sql(sqlite_CVRData, sqlite_connection, if_exists='fail')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-158b8a82ff9d> in <module>
#       1 sqlite_CVRData = "CVRData"
# ----> 2 ExtractedColumns.to_sql(sqlite_CVRData, sqlite_connection, if_exists='fail')
#
# ~\.conda\envs\Pythondata\lib\site-packages\dask\dataframe\core.py in to_sql(self, name, uri, schema, if_exists, index, index_label, chunksize, dtype, method, compute, parallel)
#    1488             method=method,
#    1489             compute=compute,
# -> 1490             parallel=parallel,
#    1491         )
#    1492
#
# ~\.conda\envs\Pythondata\lib\site-packages\dask\dataframe\io\sql.py in to_sql(df, name, uri, schema, if_exists, index, index_label, chunksize, dtype, method, compute, parallel)
#     352     """
#     353     if not isinstance(uri, str):
# --> 354         raise ValueError(f"Expected URI to be a string, got {type(uri)}.")
#     355
# ...
