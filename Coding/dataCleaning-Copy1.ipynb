# %% [markdown]
# ## Filtering and Merging 2021VAERS Datasets & Filtering Global Vaccination Dataset

# %%
# Import dependencies
import pandas as pd

from sqlalchemy import create_engine

# %% [markdown]
# ### 2021 VAERS Datasets-Data Filtering and Cleaning

# %% [markdown]
# #### 2021VAERSVAX.csv: Filter the data based on vaccination type = COVID19,  and remove unneeded columns

# %%
# Import data file
VAERSvax = "dataUsed/2021VAERSVAX.csv"

# Read data file, need the encoding to read properly
VAERSvax_raw = pd.read_csv(VAERSvax, encoding="ISO-8859-1")
display(VAERSvax_raw.head(5))
display(VAERSvax_raw.tail(5))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    916710  COVID19          MODERNA      NaN               1        IM
# 1    916741  COVID19  PFIZER\BIONTECH   EH9899               1       SYR
# 2    916742  COVID19  PFIZER\BIONTECH      NaN               1        IM
# 3    916746  COVID19          MODERNA  037K20A               1        IM
# 4    916772  COVID19  PFIZER\BIONTECH   EJ1685             UNK        IM
#
#   VAX_SITE                             VAX_NAME
# 0       LA          COVID19 (COVID19 (MODERNA))
# 1       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2      NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3       LA          COVID19 (COVID19 (MODERNA))
# 4       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
#       VAERS_ID VAX_TYPE VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 3009    983720  COVID19  MODERNA  039K20A               1        IM       LA
# 3010    983721  COVID19  MODERNA  039K20A               1        IM       RA
# 3011    983766  COVID19  MODERNA  013L20A               1        IM       RA
# 3012    983919  COVID19  MODERNA  030L20A               1        IM       LA
# 3013    985205  COVID19  MODERNA  029L20A               1        IM       UN
#
#                          VAX_NAME
# 3009  COVID19 (COVID19 (MODERNA))
# 3010  COVID19 (COVID19 (MODERNA))
# 3011  COVID19 (COVID19 (MODERNA))
# 3012  COVID19 (COVID19 (MODERNA))
# 3013  COVID19 (COVID19 (MODERNA))

# %%
# Extract the columns names
columns = list(VAERSvax_raw.columns)
columns
# Out:
# ['VAERS_ID',
#  'VAX_TYPE',
#  'VAX_MANU',
#  'VAX_LOT',
#  'VAX_DOSE_SERIES',
#  'VAX_ROUTE',
#  'VAX_SITE',
#  'VAX_NAME']

# %%
# Create a dataframe with the wanted columns only
wanted_columns = VAERSvax_raw[['VAERS_ID',
 'VAX_TYPE',
 'VAX_MANU',
 'VAX_DOSE_SERIES',
 'VAX_SITE'
]]
display(wanted_columns.head(5))
display(wanted_columns.tail(5))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 0    916710  COVID19          MODERNA               1       LA
# 1    916741  COVID19  PFIZER\BIONTECH               1       LA
# 2    916742  COVID19  PFIZER\BIONTECH               1      NaN
# 3    916746  COVID19          MODERNA               1       LA
# 4    916772  COVID19  PFIZER\BIONTECH             UNK       LA
#       VAERS_ID VAX_TYPE VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 3009    983720  COVID19  MODERNA               1       LA
# 3010    983721  COVID19  MODERNA               1       RA
# 3011    983766  COVID19  MODERNA               1       RA
# 3012    983919  COVID19  MODERNA               1       LA
# 3013    985205  COVID19  MODERNA               1       UN

# %%
# Filter the data by vax_type = COVID19
# Reset index
filtered_data = wanted_columns[wanted_columns["VAX_TYPE"]=="COVID19"]
filtered_data.reset_index(drop=True, inplace=True)
display(filtered_data.head(5))
display(filtered_data.tail(5))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 0    916710  COVID19          MODERNA               1       LA
# 1    916741  COVID19  PFIZER\BIONTECH               1       LA
# 2    916742  COVID19  PFIZER\BIONTECH               1      NaN
# 3    916746  COVID19          MODERNA               1       LA
# 4    916772  COVID19  PFIZER\BIONTECH             UNK       LA
#       VAERS_ID VAX_TYPE VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 2839    983720  COVID19  MODERNA               1       LA
# 2840    983721  COVID19  MODERNA               1       RA
# 2841    983766  COVID19  MODERNA               1       RA
# 2842    983919  COVID19  MODERNA               1       LA
# 2843    985205  COVID19  MODERNA               1       UN

# %% [markdown]
# #### 2021VAERSData.csv

# %%
# Import data file
VAERSData = "dataUsed/2021VAERSData.csv"

# Read data file, need the encoding to read properly
vaer_data_raw = pd.read_csv(VAERSData, encoding="ISO-8859-1")
display(vaer_data_raw.head(2))
display(vaer_data_raw.tail(2))
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916710  01/01/2021    MO     23.0     23.0      NaN   F      NaN
# 1    916741  01/01/2021    AR     68.0     68.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Acute appendicitis, onset morning of 1/1/2021 ...  NaN  ...
# 1  on dec 22 I felt some myalgias, chills, fatigu...  NaN  ...
#
#                                              CUR_ILL  \
# 0                                                NaN
# 1  had surgery R hand for advanced arthritis 11/1...
#
#                                              HISTORY  PRIOR_VAX SPLTTYPE  \
# 0                                     Hypothyroidism        NaN      NaN
# 1  Rheumatoid arthritis - mostly affecting R wris...        NaN      NaN
#
#    FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT   ALLERGIES
# 0          2  01/01/2021          NaN       NaN           Y        NKDA
# 1          2  01/01/2021          NaN       NaN         NaN  bee stings
#
# [2 rows x 35 columns]
#       VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 2944    983919  01/28/2021    FL     69.0     69.0      NaN   M      NaN
# 2945    985205  01/29/2021    OH     75.0     75.0      NaN   M      NaN
#
#                                            SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 2944                                              death    Y  ...     NaN
# 2945  Patient was feeling dizzy and under the weathe...    Y  ...      No
#
#      HISTORY  PRIOR_VAX SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# 2944     NaN        NaN      NaN          2  01/28/2021          NaN
# 2945    None        NaN      NaN          2  01/29/2021          NaN
#
#      OFC_VISIT ER_ED_VISIT ALLERGIES
# 2944       NaN         NaN       NaN
# 2945       NaN         NaN        No
#
# [2 rows x 35 columns]

# %%
# Extract the columns names
columns2 = list(vaer_data_raw.columns)
columns2
# Out:
# ['VAERS_ID',
#  'RECVDATE',
#  'STATE',
#  'AGE_YRS',
#  'CAGE_YR',
#  'CAGE_MO',
#  'SEX',
#  'RPT_DATE',
#  'SYMPTOM_TEXT',
#  'DIED',
#  'DATEDIED',
#  'L_THREAT',
#  'ER_VISIT',
#  'HOSPITAL',
#  'HOSPDAYS',
#  'X_STAY',
#  'DISABLE',
#  'RECOVD',
#  'VAX_DATE',
#  'ONSET_DATE',
#  'NUMDAYS',
#  'LAB_DATA',
#  'V_ADMINBY',
#  'V_FUNDBY',
#  'OTHER_MEDS',
#  'CUR_ILL',
#  'HISTORY',
#  'PRIOR_VAX',
#  'SPLTTYPE',
#  'FORM_VERS',
#  'TODAYS_DATE',
#  'BIRTH_DEFECT',
#  'OFC_VISIT',
#  'ER_ED_VISIT',
#  'ALLERGIES']

# %%
# Create a dataframe with the wanted columns only
wanted_columns2 = vaer_data_raw[['VAERS_ID',
 'STATE',
 'AGE_YRS',
 'SEX',
 'DIED',
 'DATEDIED',
 'L_THREAT',
 'ER_VISIT',
 'HOSPITAL',
 'HOSPDAYS',
 'X_STAY',
 'DISABLE',
 'RECOVD',
 'VAX_DATE',
 'ONSET_DATE',
 'NUMDAYS'
]]
wanted_columns2.head(5)
# Out:
#    VAERS_ID STATE  AGE_YRS SEX DIED DATEDIED L_THREAT  ER_VISIT HOSPITAL  \
# 0    916710    MO     23.0   F  NaN      NaN        Y       NaN        Y
# 1    916741    AR     68.0   F  NaN      NaN      NaN       NaN      NaN
# 2    916742    MN     29.0   F  NaN      NaN        Y       NaN        Y
# 3    916746    TX     49.0   F  NaN      NaN        Y       NaN      NaN
# 4    916772    GA     55.0   M  NaN      NaN      NaN       NaN      NaN
#
#    HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  ONSET_DATE  NUMDAYS
# 0       NaN    NaN     NaN      U  12/29/2020  01/01/2021      3.0
# 1       NaN    NaN       Y      N  12/21/2020  12/22/2020      1.0
# 2       4.0    NaN     NaN      U  12/29/2020  12/29/2020      0.0
# 3       NaN    NaN     NaN      Y  12/28/2020  12/28/2020      0.0
# 4       NaN    NaN     NaN      U  12/22/2020  12/26/2020      4.0

# %% [markdown]
# #### 2021VAERSSymptoms.csv

# %%
# Import data file
VAERSsymptoms = "dataUsed/2021VAERSSYMPTOMS.csv"

# Read data file, need the encoding to read properly
vaer_symptoms_raw = pd.read_csv(VAERSsymptoms, encoding="ISO-8859-1")
display(vaer_symptoms_raw.head(2))
display(vaer_symptoms_raw.tail(2))
# Out:
#    VAERS_ID      SYMPTOM1  SYMPTOMVERSION1  \
# 0    916710  Appendicitis             23.1
# 1    916741        Chills             23.1
#
#                                SYMPTOM2  SYMPTOMVERSION2 SYMPTOM3  \
# 0  Band neutrophil percentage increased             23.1  Surgery
# 1        Complex regional pain syndrome             23.1  Fatigue
#
#    SYMPTOMVERSION3                          SYMPTOM4  SYMPTOMVERSION4  \
# 0             23.1  White blood cell count increased             23.1
# 1             23.1                          Headache             23.1
#
#                           SYMPTOM5  SYMPTOMVERSION5
# 0                              NaN              NaN
# 1  Joint range of motion decreased             23.1
#       VAERS_ID SYMPTOM1  SYMPTOMVERSION1   SYMPTOM2  SYMPTOMVERSION2 SYMPTOM3  \
# 4710    983919    Death             23.1        NaN              NaN      NaN
# 4711    985205    Death             23.1  Dizziness             23.1  Malaise
#
#       SYMPTOMVERSION3 SYMPTOM4  SYMPTOMVERSION4 SYMPTOM5  SYMPTOMVERSION5
# 4710              NaN      NaN              NaN      NaN              NaN
# 4711             23.1      NaN              NaN      NaN              NaN

# %%
# Extract the columns names
columns3 = list(vaer_symptoms_raw.columns)
columns3
# Out:
# ['VAERS_ID',
#  'SYMPTOM1',
#  'SYMPTOMVERSION1',
#  'SYMPTOM2',
#  'SYMPTOMVERSION2',
#  'SYMPTOM3',
#  'SYMPTOMVERSION3',
#  'SYMPTOM4',
#  'SYMPTOMVERSION4',
#  'SYMPTOM5',
#  'SYMPTOMVERSION5']

# %%
# Create a dataframe with the wanted columns only
wanted_columns3 = vaer_symptoms_raw[['VAERS_ID',
 'SYMPTOM1',
 'SYMPTOM2',
 'SYMPTOM3',
 'SYMPTOM4',
 'SYMPTOM5'
]]
wanted_columns3.tail(5)
# Out:
#       VAERS_ID                                  SYMPTOM1  \
# 4707    983721                                     Death
# 4708    983766                        Blood pH decreased
# 4709    983766  International normalised ratio increased
# 4710    983919                                     Death
# 4711    985205                                     Death
#
#                                                SYMPTOM2  \
# 4707                                                NaN
# 4708                              Cardiac failure acute
# 4709  N-terminal prohormone brain natriuretic peptid...
# 4710                                                NaN
# 4711                                          Dizziness
#
#                       SYMPTOM3 SYMPTOM4  SYMPTOM5
# 4707                       NaN      NaN       NaN
# 4708          Chest discomfort    Death  Dyspnoea
# 4709  SARS-CoV-2 test negative      NaN       NaN
# 4710                       NaN      NaN       NaN
# 4711                   Malaise      NaN       NaN

# %% [markdown]
# ### 2021 VAERS Datasets-Merging

# %%
# Merge the two organized dataframes
merge_2data = pd.merge(filtered_data,wanted_columns2, on="VAERS_ID", how="left")
display(merge_2data.head(2))
display(merge_2data.tail(2))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE STATE  AGE_YRS  \
# 0    916710  COVID19          MODERNA               1       LA    MO     23.0
# 1    916741  COVID19  PFIZER\BIONTECH               1       LA    AR     68.0
#
#   SEX DIED DATEDIED L_THREAT  ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE  \
# 0   F  NaN      NaN        Y       NaN        Y       NaN    NaN     NaN
# 1   F  NaN      NaN      NaN       NaN      NaN       NaN    NaN       Y
#
#   RECOVD    VAX_DATE  ONSET_DATE  NUMDAYS
# 0      U  12/29/2020  01/01/2021      3.0
# 1      N  12/21/2020  12/22/2020      1.0
#       VAERS_ID VAX_TYPE VAX_MANU VAX_DOSE_SERIES VAX_SITE STATE  AGE_YRS SEX  \
# 2842    983919  COVID19  MODERNA               1       LA    FL     69.0   M
# 2843    985205  COVID19  MODERNA               1       UN    OH     75.0   M
#
#      DIED    DATEDIED L_THREAT  ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE  \
# 2842    Y         NaN      NaN       NaN      NaN       NaN    NaN     NaN
# 2843    Y  01/26/2021      NaN       NaN      NaN       NaN    NaN     NaN
#
#      RECOVD    VAX_DATE  ONSET_DATE  NUMDAYS
# 2842    NaN  01/21/2021  01/01/2021      NaN
# 2843      N  01/25/2021  01/26/2021      1.0

# %%
# Merge all three organized dataframes
merge_all = pd.merge(merge_2data,wanted_columns3,on="VAERS_ID", how="left")
display(merge_all.head(4))
display(merge_all.tail(4))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE STATE  AGE_YRS  \
# 0    916710  COVID19          MODERNA               1       LA    MO     23.0
# 1    916741  COVID19  PFIZER\BIONTECH               1       LA    AR     68.0
# 2    916741  COVID19  PFIZER\BIONTECH               1       LA    AR     68.0
# 3    916742  COVID19  PFIZER\BIONTECH               1      NaN    MN     29.0
#
#   SEX DIED DATEDIED  ... DISABLE  RECOVD    VAX_DATE  ONSET_DATE NUMDAYS  \
# 0   F  NaN      NaN  ...     NaN       U  12/29/2020  01/01/2021     3.0
# 1   F  NaN      NaN  ...       Y       N  12/21/2020  12/22/2020     1.0
# 2   F  NaN      NaN  ...       Y       N  12/21/2020  12/22/2020     1.0
# 3   F  NaN      NaN  ...     NaN       U  12/29/2020  12/29/2020     0.0
#
#                 SYMPTOM1                              SYMPTOM2  \
# 0           Appendicitis  Band neutrophil percentage increased
# 1                 Chills        Complex regional pain syndrome
# 2                Myalgia                     Pain in extremity
# 3  Anaphylactic reaction                            Blood test
#
#               SYMPTOM3                          SYMPTOM4  \
# 0              Surgery  White blood cell count increased
# 1              Fatigue                          Headache
# 2  Peripheral swelling                    X-ray abnormal
# 3    Burning sensation    Central venous catheterisation
#
#                           SYMPTOM5
# 0                              NaN
# 1  Joint range of motion decreased
# 2                              NaN
# 3                        Dysphonia
#
# [4 rows x 25 columns]
#       VAERS_ID VAX_TYPE VAX_MANU VAX_DOSE_SERIES VAX_SITE STATE  AGE_YRS SEX  \
# 4563    983766  COVID19  MODERNA               1       RA    NC     90.0   F
# 4564    983766  COVID19  MODERNA               1       RA    NC     90.0   F
# 4565    983919  COVID19  MODERNA               1       LA    FL     69.0   M
# 4566    985205  COVID19  MODERNA               1       UN    OH     75.0   M
#
#      DIED    DATEDIED  ... DISABLE  RECOVD    VAX_DATE  ONSET_DATE NUMDAYS  \
# 4563    Y  01/24/2021  ...     NaN       N  01/16/2021  01/21/2021     5.0
# 4564    Y  01/24/2021  ...     NaN       N  01/16/2021  01/21/2021     5.0
# 4565    Y         NaN  ...     NaN     NaN  01/21/2021  01/01/2021     NaN
# 4566    Y  01/26/2021  ...     NaN       N  01/25/2021  01/26/2021     1.0
#
#                                       SYMPTOM1  \
# 4563                        Blood pH decreased
# 4564  International normalised ratio increased
# 4565                                     Death
# 4566                                     Death
#
#                                                SYMPTOM2  \
# 4563                              Cardiac failure acute
# 4564  N-terminal prohormone brain natriuretic peptid...
# 4565                                                NaN
# 4566                                          Dizziness
#
#                       SYMPTOM3 SYMPTOM4  SYMPTOM5
# 4563          Chest discomfort    Death  Dyspnoea
# 4564  SARS-CoV-2 test negative      NaN       NaN
# 4565                       NaN      NaN       NaN
# 4566                   Malaise      NaN       NaN
#
# [4 rows x 25 columns]

# %% [markdown]
# ### World Wide Dataset-Data Cleaning

# %%
# Import data file
worldWideData = "dataUsed/WorldWideData.csv"

# Read data file, need the encoding to read properly
world_raw = pd.read_csv(worldWideData, encoding="ISO-8859-1")
display(world_raw.head(2))
display(world_raw.tail(2))
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
#
# [2 rows x 59 columns]
#       iso_code continent  location        date  total_cases  new_cases  \
# 67893      ZWE    Africa  Zimbabwe  2021-02-08      34658.0      106.0
# 67894      ZWE    Africa  Zimbabwe  2021-02-09      34781.0      123.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 67893             158.571        1339.0        13.0               15.000  ...
# 67894             138.143        1353.0        14.0               14.143  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 67893        1899.775             21.4                307.846
# 67894        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 67893                 1.82             1.6          30.7
# 67894                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 67893                  36.791                         1.7            61.49
# 67894                  36.791                         1.7            61.49
#
#        human_development_index
# 67893                    0.571
# 67894                    0.571
#
# [2 rows x 59 columns]

# %%
# Extract the columns names
columns4 = list(world_raw.columns)
columns4
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'new_vaccinations',
#  'new_vaccinations_smoothed',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'new_vaccinations_smoothed_per_million',
#  'stringency_index',
#  'population',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'female_smokers',
#  'male_smokers',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index']

# %%
# Create a dataframe with the wanted columns only
wanted_columns4 = world_raw[['iso_code',
 'continent',
 'location',
 'date',
 'total_cases',
 'new_cases' , 
 'total_deaths',
 'new_deaths',
 'total_tests',
 'positive_rate',
 'total_vaccinations',
 'people_vaccinated',
 'people_fully_vaccinated',
 'new_vaccinations',
 'population',
 'median_age',
 'aged_65_older',
 'aged_70_older'
]]
display(wanted_columns4.head(4))
display(wanted_columns4.tail(4))
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
#
#    total_deaths  new_deaths  total_tests  positive_rate  total_vaccinations  \
# 0           NaN         NaN          NaN            NaN                 NaN
# 1           NaN         NaN          NaN            NaN                 NaN
# 2           NaN         NaN          NaN            NaN                 NaN
# 3           NaN         NaN          NaN            NaN                 NaN
#
#    people_vaccinated  people_fully_vaccinated  new_vaccinations  population  \
# 0                NaN                      NaN               NaN  38928341.0
# 1                NaN                      NaN               NaN  38928341.0
# 2                NaN                      NaN               NaN  38928341.0
# 3                NaN                      NaN               NaN  38928341.0
#
#    median_age  aged_65_older  aged_70_older
# 0        18.6          2.581          1.337
# 1        18.6          2.581          1.337
# 2        18.6          2.581          1.337
# 3        18.6          2.581          1.337
#       iso_code continent  location        date  total_cases  new_cases  \
# 67891      ZWE    Africa  Zimbabwe  2021-02-06      34487.0      156.0
# 67892      ZWE    Africa  Zimbabwe  2021-02-07      34552.0       65.0
# 67893      ZWE    Africa  Zimbabwe  2021-02-08      34658.0      106.0
# 67894      ZWE    Africa  Zimbabwe  2021-02-09      34781.0      123.0
#
#        total_deaths  new_deaths  total_tests  positive_rate  \
# 67891        1316.0        13.0     335489.0          0.064
# 67892        1326.0        10.0     336553.0          0.064
# 67893        1339.0        13.0          NaN            NaN
# 67894        1353.0        14.0          NaN            NaN
#
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 67891                 NaN                NaN                      NaN
# 67892                 NaN                NaN                      NaN
# 67893                 NaN                NaN                      NaN
# 67894                 NaN                NaN                      NaN
#
#        new_vaccinations  population  median_age  aged_65_older  aged_70_older
# 67891               NaN  14862927.0        19.6          2.822          1.882
# 67892               NaN  14862927.0        19.6          2.822          1.882
# 67893               NaN  14862927.0        19.6          2.822          1.882
# 67894               NaN  14862927.0        19.6          2.822          1.882

# %%
latlng = "dataUsed/world_country_and_usa_states_latitude_and_longitude_values.csv"

latlng_raw = pd.read_csv(latlng)
latlng_raw.head()
# Out:
#   country_code   latitude  longitude               country usa_state_code  \
# 0           AD  42.546245   1.601554               Andorra             AK
# 1           AE  23.424076  53.847818  United Arab Emirates             AL
# 2           AF  33.939110  67.709953           Afghanistan             AR
# 3           AG  17.060816 -61.796428   Antigua and Barbuda             AZ
# 4           AI  18.220554 -63.068615              Anguilla             CA
#
#    usa_state_latitude  usa_state_longitude   usa_state
# 0           63.588753          -154.493062      Alaska
# 1           32.318231           -86.902298     Alabama
# 2           35.201050           -91.831833    Arkansas
# 3           34.048928          -111.093731     Arizona
# 4           36.778261          -119.417932  California

# %%
latlng_world = latlng_raw[[
    "latitude",
    "longitude",
    "country"
]]

latlng_world = latlng_world.rename(columns = {"country":"location"})
latlng_world.head()
# Out:
#     latitude  longitude              location
# 0  42.546245   1.601554               Andorra
# 1  23.424076  53.847818  United Arab Emirates
# 2  33.939110  67.709953           Afghanistan
# 3  17.060816 -61.796428   Antigua and Barbuda
# 4  18.220554 -63.068615              Anguilla

# %%
merged_db = pd.merge(wanted_columns4, latlng_world, on = "location", how = "left")
merged_db.copy()
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 67890      ZWE    Africa     Zimbabwe  2021-02-05      34331.0      160.0
# 67891      ZWE    Africa     Zimbabwe  2021-02-06      34487.0      156.0
# 67892      ZWE    Africa     Zimbabwe  2021-02-07      34552.0       65.0
# 67893      ZWE    Africa     Zimbabwe  2021-02-08      34658.0      106.0
# 67894      ZWE    Africa     Zimbabwe  2021-02-09      34781.0      123.0
#
#        total_deaths  new_deaths  total_tests  positive_rate  \
# 0               NaN         NaN          NaN            NaN
# 1               NaN         NaN          NaN            NaN
# 2               NaN         NaN          NaN            NaN
# 3               NaN         NaN          NaN            NaN
# 4               NaN         NaN          NaN            NaN
# ...             ...         ...          ...            ...
# 67890        1303.0        15.0     333403.0          0.073
# 67891        1316.0        13.0     335489.0          0.064
# 67892        1326.0        10.0     336553.0          0.064
# 67893        1339.0        13.0          NaN            NaN
# 67894        1353.0        14.0          NaN            NaN
#
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                     NaN                NaN                      NaN
# 1                     NaN                NaN                      NaN
# 2                     NaN                NaN                      NaN
# 3                     NaN                NaN                      NaN
# 4                     NaN                NaN                      NaN
# ...                   ...                ...                      ...
# 67890                 NaN                NaN                      NaN
# 67891                 NaN                NaN                      NaN
# 67892                 NaN                NaN                      NaN
# 67893                 NaN                NaN                      NaN
# 67894                 NaN                NaN                      NaN
#
#        new_vaccinations  population  median_age  aged_65_older  aged_70_older  \
# 0                   NaN  38928341.0        18.6          2.581          1.337
# 1                   NaN  38928341.0        18.6          2.581          1.337
# 2                   NaN  38928341.0        18.6          2.581          1.337
# 3                   NaN  38928341.0        18.6          2.581          1.337
# 4                   NaN  38928341.0        18.6          2.581          1.337
# ...                 ...         ...         ...            ...            ...
# 67890               NaN  14862927.0        19.6          2.822          1.882
# 67891               NaN  14862927.0        19.6          2.822          1.882
# 67892               NaN  14862927.0        19.6          2.822          1.882
# 67893               NaN  14862927.0        19.6          2.822          1.882
# 67894               NaN  14862927.0        19.6          2.822          1.882
#
#         latitude  longitude
# 0      33.939110  67.709953
# 1      33.939110  67.709953
# 2      33.939110  67.709953
# 3      33.939110  67.709953
# 4      33.939110  67.709953
# ...          ...        ...
# 67890 -19.015438  29.154857
# 67891 -19.015438  29.154857
# 67892 -19.015438  29.154857
# 67893 -19.015438  29.154857
# 67894 -19.015438  29.154857
#
# [67895 rows x 20 columns]

# %%
cleaned_df = merged_db.dropna()

# %%
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lon],row[lat]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
cols = [
     'iso_code',
     'continent',
     'location',
     'date',
     'total_cases',
     'new_cases' , 
     'total_deaths',
     'new_deaths',
     'total_tests',
     'positive_rate',
     'total_vaccinations',
     'people_vaccinated',
     'people_fully_vaccinated',
     'new_vaccinations',
     'population',
     'median_age',
     'aged_65_older',
     'aged_70_older',       
   ]

geojson = df_to_geojson(cleaned_df, cols)
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-21',
#     'total_cases': 1843077.0,
#     'new_cases': 11396.0,
#     'total_deaths': 46355.0,
#     'new_deaths': 139.0,
#     'total_tests': 5017855.0,
#     'positive_rate': 0.257,
#     'total_vaccinations': 265724.0,
#     'people_vaccinated': 249372.0,
#     'people_fully_vaccinated': 16352.0,
#     'new_vaccinations': 17791.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-22',
#     'total_cases': 1853830.0,
#     'new_cases': 10753.0,
#     'total_deaths': 46575.0,
#     'new_deaths': 220.0,
#     'total_tests': 5057091.0,
#     'positive_rate': 0.258,
#     'total_vaccinations': 279602.0,
#     'people_vaccinated': 254456.0,
#     'people_fully_vaccinated': 25146.0,
#     'new_vaccinations': 13878.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-23',
#     'total_cases': 1862192.0,
#     'new_cases': 8362.0,
#     'total_deaths': 46737.0,
#     'new_deaths': 162.0,
#     'total_tests': 5085646.0,
#     'positive_rate': 0.264,
#     'total_vaccinations': 288064.0,
#     'people_vaccinated': 258876.0,
#     'people_fully_vaccinated': 29188.0,
#     'new_vaccinations': 8462.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-24',
#     'total_cases': 1867223.0,
#     'new_cases': 5031.0,
#     'total_deaths': 46827.0,
#     'new_deaths': 90.0,
#     'total_tests': 5105622.0,
#     'positive_rate': 0.26,
#     'total_vaccinations': 292023.0,
#     'people_vaccinated': 260036.0,
#     'people_fully_vaccinated': 31987.0,
#     'new_vaccinations': 3959.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-25',
#     'total_cases': 1874801.0,
#     'new_cases': 7578.0,
#     'total_deaths': 47034.0,
#     'new_deaths': 207.0,
#     'total_tests': 5144717.0,
#     'positive_rate': 0.262,
#     'total_vaccinations': 292386.0,
#     'people_vaccinated': 260122.0,
#     'people_fully_vaccinated': 32264.0,
#     'new_vaccinations': 363.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-26',
#     'total_cases': 1885210.0,
#     'new_cases': 10409.0,
#     'total_deaths': 47253.0,
#     'new_deaths': 219.0,
#     'total_tests': 5183096.0,
#     'positive_rate': 0.263,
#     'total_vaccinations': 305880.0,
#     'people_vaccinated': 266969.0,
#     'people_fully_vaccinated': 38911.0,
#     'new_vaccinations': 13494.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-27',
#     'total_cases': 1896053.0,
#     'new_cases': 10843.0,
#     'total_deaths': 47435.0,
#     'new_deaths': 182.0,
#     'total_tests': 5222009.0,
#     'positive_rate': 0.263,
#     'total_vaccinations': 318033.0,
#     'people_vaccinated': 272323.0,
#     'people_fully_vaccinated': 45710.0,
#     'new_vaccinations': 12153.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-28',
#     'total_cases': 1905524.0,
#     'new_cases': 9471.0,
#     'total_deaths': 47601.0,
#     'new_deaths': 166.0,
#     'total_tests': 5257041.0,
#     'positive_rate': 0.261,
#     'total_vaccinations': 327999.0,
#     'people_vaccinated': 276548.0,
#     'people_fully_vaccinated': 51451.0,
#     'new_vaccinations': 9966.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-29',
#     'total_cases': 1915362.0,
#     'new_cases': 9838.0,
#     'total_deaths': 47775.0,
#     'new_deaths': 174.0,
#     'total_tests': 5293661.0,
#     'positive_rate': 0.26,
#     'total_vaccinations': 344034.0,
#     'people_vaccinated': 278451.0,
#     'people_fully_vaccinated': 65583.0,
#     'new_vaccinations': 16035.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'ARG',
#     'continent': 'South America',
#     'location': 'Argentina',
#     'date': '2021-01-30',
#     'total_cases': 1922264.0,
#     'new_cases': 6902.0,
#     'total_deaths': 47931.0,
#     'new_deaths': 156.0,
#     'total_tests': 5326841.0,
#     'positive_rate': 0.249,
#     'total_vaccinations': 366384.0,
#     'people_vaccinated': 281023.0,
#     'people_fully_vaccinated': 85361.0,
#     'new_vaccinations': 22350.0,
#     'population': 45195777.0,
#     'median_age': 31.9,
#     'aged_65_older': 11.198,
#     'aged_70_older': 7.441},
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.616671999999994, -38.416097]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-18',
#     'total_cases': 679771.0,
#     'new_cases': 932.0,
#     'total_deaths': 20472.0,
#     'new_deaths': 37.0,
#     'total_tests': 7658782.0,
#     'positive_rate': 0.054000000000000006,
#     'total_vaccinations': 132383.0,
#     'people_vaccinated': 132274.0,
#     'people_fully_vaccinated': 109.0,
#     'new_vaccinations': 10450.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-19',
#     'total_cases': 681250.0,
#     'new_cases': 1479.0,
#     'total_deaths': 20554.0,
#     'new_deaths': 82.0,
#     'total_tests': 7722069.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 150921.0,
#     'people_vaccinated': 150631.0,
#     'people_fully_vaccinated': 290.0,
#     'new_vaccinations': 18538.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-20',
#     'total_cases': 684256.0,
#     'new_cases': 3006.0,
#     'total_deaths': 20572.0,
#     'new_deaths': 18.0,
#     'total_tests': 7775530.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 171294.0,
#     'people_vaccinated': 170582.0,
#     'people_fully_vaccinated': 712.0,
#     'new_vaccinations': 20373.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-21',
#     'total_cases': 686827.0,
#     'new_cases': 2571.0,
#     'total_deaths': 20620.0,
#     'new_deaths': 48.0,
#     'total_tests': 7821095.0,
#     'positive_rate': 0.055999999999999994,
#     'total_vaccinations': 200693.0,
#     'people_vaccinated': 199981.0,
#     'people_fully_vaccinated': 712.0,
#     'new_vaccinations': 29399.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-22',
#     'total_cases': 689271.0,
#     'new_cases': 2444.0,
#     'total_deaths': 20675.0,
#     'new_deaths': 55.0,
#     'total_tests': 7871211.0,
#     'positive_rate': 0.055999999999999994,
#     'total_vaccinations': 229386.0,
#     'people_vaccinated': 228643.0,
#     'people_fully_vaccinated': 743.0,
#     'new_vaccinations': 28693.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-23',
#     'total_cases': 691854.0,
#     'new_cases': 2583.0,
#     'total_deaths': 20726.0,
#     'new_deaths': 51.0,
#     'total_tests': 7908838.0,
#     'positive_rate': 0.055999999999999994,
#     'total_vaccinations': 237242.0,
#     'people_vaccinated': 236492.0,
#     'people_fully_vaccinated': 750.0,
#     'new_vaccinations': 7856.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-24',
#     'total_cases': 693666.0,
#     'new_cases': 1812.0,
#     'total_deaths': 20779.0,
#     'new_deaths': 53.0,
#     'total_tests': 7930522.0,
#     'positive_rate': 0.055999999999999994,
#     'total_vaccinations': 239088.0,
#     'people_vaccinated': 238338.0,
#     'people_fully_vaccinated': 750.0,
#     'new_vaccinations': 1846.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-25',
#     'total_cases': 694858.0,
#     'new_cases': 1192.0,
#     'total_deaths': 20814.0,
#     'new_deaths': 35.0,
#     'total_tests': 7974789.0,
#     'positive_rate': 0.055999999999999994,
#     'total_vaccinations': 249630.0,
#     'people_vaccinated': 248880.0,
#     'people_fully_vaccinated': 750.0,
#     'new_vaccinations': 10542.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-26',
#     'total_cases': 696642.0,
#     'new_cases': 1784.0,
#     'total_deaths': 20879.0,
#     'new_deaths': 65.0,
#     'total_tests': 8039490.0,
#     'positive_rate': 0.055999999999999994,
#     'total_vaccinations': 261063.0,
#     'people_vaccinated': 258955.0,
#     'people_fully_vaccinated': 2108.0,
#     'new_vaccinations': 11433.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-27',
#     'total_cases': 699662.0,
#     'new_cases': 3020.0,
#     'total_deaths': 20933.0,
#     'new_deaths': 54.0,
#     'total_tests': 8099741.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 276921.0,
#     'people_vaccinated': 271713.0,
#     'people_fully_vaccinated': 5208.0,
#     'new_vaccinations': 15858.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-28',
#     'total_cases': 702437.0,
#     'new_cases': 2775.0,
#     'total_deaths': 20982.0,
#     'new_deaths': 49.0,
#     'total_tests': 8153354.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 298594.0,
#     'people_vaccinated': 286354.0,
#     'people_fully_vaccinated': 12240.0,
#     'new_vaccinations': 21673.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-29',
#     'total_cases': 705120.0,
#     'new_cases': 2683.0,
#     'total_deaths': 21018.0,
#     'new_deaths': 36.0,
#     'total_tests': 8207875.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 317304.0,
#     'people_vaccinated': 297356.0,
#     'people_fully_vaccinated': 19948.0,
#     'new_vaccinations': 18710.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-30',
#     'total_cases': 707837.0,
#     'new_cases': 2717.0,
#     'total_deaths': 21066.0,
#     'new_deaths': 48.0,
#     'total_tests': 8254969.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 321479.0,
#     'people_vaccinated': 298891.0,
#     'people_fully_vaccinated': 22588.0,
#     'new_vaccinations': 4175.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-01-31',
#     'total_cases': 710153.0,
#     'new_cases': 2316.0,
#     'total_deaths': 21092.0,
#     'new_deaths': 26.0,
#     'total_tests': 8277096.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 322370.0,
#     'people_vaccinated': 299454.0,
#     'people_fully_vaccinated': 22916.0,
#     'new_vaccinations': 891.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-02-01',
#     'total_cases': 711417.0,
#     'new_cases': 1264.0,
#     'total_deaths': 21124.0,
#     'new_deaths': 32.0,
#     'total_tests': 8322897.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 329204.0,
#     'people_vaccinated': 303043.0,
#     'people_fully_vaccinated': 26161.0,
#     'new_vaccinations': 6834.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-02-02',
#     'total_cases': 713271.0,
#     'new_cases': 1854.0,
#     'total_deaths': 21173.0,
#     'new_deaths': 49.0,
#     'total_tests': 8391132.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 350621.0,
#     'people_vaccinated': 312091.0,
#     'people_fully_vaccinated': 38530.0,
#     'new_vaccinations': 21417.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-02-03',
#     'total_cases': 716395.0,
#     'new_cases': 3124.0,
#     'total_deaths': 21216.0,
#     'new_deaths': 43.0,
#     'total_tests': 8451815.0,
#     'positive_rate': 0.054000000000000006,
#     'total_vaccinations': 377264.0,
#     'people_vaccinated': 321042.0,
#     'people_fully_vaccinated': 56222.0,
#     'new_vaccinations': 26643.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-02-04',
#     'total_cases': 718847.0,
#     'new_cases': 2452.0,
#     'total_deaths': 21260.0,
#     'new_deaths': 44.0,
#     'total_tests': 8505836.0,
#     'positive_rate': 0.054000000000000006,
#     'total_vaccinations': 404998.0,
#     'people_vaccinated': 328671.0,
#     'people_fully_vaccinated': 76327.0,
#     'new_vaccinations': 27734.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-02-05',
#     'total_cases': 721432.0,
#     'new_cases': 2585.0,
#     'total_deaths': 21295.0,
#     'new_deaths': 35.0,
#     'total_tests': 8559469.0,
#     'positive_rate': 0.053,
#     'total_vaccinations': 429699.0,
#     'people_vaccinated': 334629.0,
#     'people_fully_vaccinated': 95070.0,
#     'new_vaccinations': 24701.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BEL',
#     'continent': 'Europe',
#     'location': 'Belgium',
#     'date': '2021-02-06',
#     'total_cases': 723870.0,
#     'new_cases': 2438.0,
#     'total_deaths': 21352.0,
#     'new_deaths': 57.0,
#     'total_tests': 8598273.0,
#     'positive_rate': 0.052000000000000005,
#     'total_vaccinations': 434788.0,
#     'people_vaccinated': 335541.0,
#     'people_fully_vaccinated': 99247.0,
#     'new_vaccinations': 5089.0,
#     'population': 11589616.0,
#     'median_age': 41.8,
#     'aged_65_older': 18.570999999999998,
#     'aged_70_older': 12.849},
#    'geometry': {'type': 'Point', 'coordinates': [4.469936, 50.503887]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-18',
#     'total_cases': 212383.0,
#     'new_cases': 570.0,
#     'total_deaths': 8565.0,
#     'new_deaths': 82.0,
#     'total_tests': 1269647.0,
#     'positive_rate': 0.069,
#     'total_vaccinations': 19638.0,
#     'people_vaccinated': 18524.0,
#     'people_fully_vaccinated': 1114.0,
#     'new_vaccinations': 1185.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-19',
#     'total_cases': 212927.0,
#     'new_cases': 544.0,
#     'total_deaths': 8614.0,
#     'new_deaths': 49.0,
#     'total_tests': 1277606.0,
#     'positive_rate': 0.064,
#     'total_vaccinations': 22226.0,
#     'people_vaccinated': 19058.0,
#     'people_fully_vaccinated': 3168.0,
#     'new_vaccinations': 2588.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-20',
#     'total_cases': 213409.0,
#     'new_cases': 482.0,
#     'total_deaths': 8651.0,
#     'new_deaths': 37.0,
#     'total_tests': 1285526.0,
#     'positive_rate': 0.066,
#     'total_vaccinations': 24127.0,
#     'people_vaccinated': 19834.0,
#     'people_fully_vaccinated': 4293.0,
#     'new_vaccinations': 1901.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-21',
#     'total_cases': 213864.0,
#     'new_cases': 455.0,
#     'total_deaths': 8741.0,
#     'new_deaths': 90.0,
#     'total_tests': 1293578.0,
#     'positive_rate': 0.063,
#     'total_vaccinations': 25251.0,
#     'people_vaccinated': 20719.0,
#     'people_fully_vaccinated': 4532.0,
#     'new_vaccinations': 1124.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-22',
#     'total_cases': 214430.0,
#     'new_cases': 566.0,
#     'total_deaths': 8799.0,
#     'new_deaths': 58.0,
#     'total_tests': 1301250.0,
#     'positive_rate': 0.063,
#     'total_vaccinations': 26101.0,
#     'people_vaccinated': 21496.0,
#     'people_fully_vaccinated': 4605.0,
#     'new_vaccinations': 850.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-23',
#     'total_cases': 214696.0,
#     'new_cases': 266.0,
#     'total_deaths': 8811.0,
#     'new_deaths': 12.0,
#     'total_tests': 1311036.0,
#     'positive_rate': 0.063,
#     'total_vaccinations': 26119.0,
#     'people_vaccinated': 21509.0,
#     'people_fully_vaccinated': 4610.0,
#     'new_vaccinations': 18.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-24',
#     'total_cases': 214817.0,
#     'new_cases': 121.0,
#     'total_deaths': 8820.0,
#     'new_deaths': 9.0,
#     'total_tests': 1315515.0,
#     'positive_rate': 0.064,
#     'total_vaccinations': 26143.0,
#     'people_vaccinated': 21533.0,
#     'people_fully_vaccinated': 4610.0,
#     'new_vaccinations': 24.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-25',
#     'total_cases': 215589.0,
#     'new_cases': 772.0,
#     'total_deaths': 8880.0,
#     'new_deaths': 60.0,
#     'total_tests': 1316722.0,
#     'positive_rate': 0.068,
#     'total_vaccinations': 26798.0,
#     'people_vaccinated': 22129.0,
#     'people_fully_vaccinated': 4669.0,
#     'new_vaccinations': 655.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-26',
#     'total_cases': 216416.0,
#     'new_cases': 827.0,
#     'total_deaths': 8916.0,
#     'new_deaths': 36.0,
#     'total_tests': 1330261.0,
#     'positive_rate': 0.066,
#     'total_vaccinations': 29122.0,
#     'people_vaccinated': 23667.0,
#     'people_fully_vaccinated': 5455.0,
#     'new_vaccinations': 2324.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-27',
#     'total_cases': 217014.0,
#     'new_cases': 598.0,
#     'total_deaths': 8944.0,
#     'new_deaths': 28.0,
#     'total_tests': 1345912.0,
#     'positive_rate': 0.06,
#     'total_vaccinations': 32917.0,
#     'people_vaccinated': 25245.0,
#     'people_fully_vaccinated': 7672.0,
#     'new_vaccinations': 3795.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-28',
#     'total_cases': 217574.0,
#     'new_cases': 560.0,
#     'total_deaths': 8973.0,
#     'new_deaths': 29.0,
#     'total_tests': 1359188.0,
#     'positive_rate': 0.057,
#     'total_vaccinations': 37636.0,
#     'people_vaccinated': 26753.0,
#     'people_fully_vaccinated': 10883.0,
#     'new_vaccinations': 4719.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-29',
#     'total_cases': 218269.0,
#     'new_cases': 695.0,
#     'total_deaths': 9008.0,
#     'new_deaths': 35.0,
#     'total_tests': 1371485.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 40805.0,
#     'people_vaccinated': 27856.0,
#     'people_fully_vaccinated': 12949.0,
#     'new_vaccinations': 3169.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-30',
#     'total_cases': 218618.0,
#     'new_cases': 349.0,
#     'total_deaths': 9028.0,
#     'new_deaths': 20.0,
#     'total_tests': 1385067.0,
#     'positive_rate': 0.053,
#     'total_vaccinations': 41020.0,
#     'people_vaccinated': 27957.0,
#     'people_fully_vaccinated': 13063.0,
#     'new_vaccinations': 215.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-01-31',
#     'total_cases': 218748.0,
#     'new_cases': 130.0,
#     'total_deaths': 9045.0,
#     'new_deaths': 17.0,
#     'total_tests': 1389599.0,
#     'positive_rate': 0.053,
#     'total_vaccinations': 41125.0,
#     'people_vaccinated': 28041.0,
#     'people_fully_vaccinated': 13084.0,
#     'new_vaccinations': 105.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-02-01',
#     'total_cases': 219580.0,
#     'new_cases': 832.0,
#     'total_deaths': 9142.0,
#     'new_deaths': 97.0,
#     'total_tests': 1391560.0,
#     'positive_rate': 0.053,
#     'total_vaccinations': 42634.0,
#     'people_vaccinated': 28978.0,
#     'people_fully_vaccinated': 13656.0,
#     'new_vaccinations': 1509.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-02-02',
#     'total_cases': 220547.0,
#     'new_cases': 967.0,
#     'total_deaths': 9178.0,
#     'new_deaths': 36.0,
#     'total_tests': 1403129.0,
#     'positive_rate': 0.057,
#     'total_vaccinations': 45917.0,
#     'people_vaccinated': 30817.0,
#     'people_fully_vaccinated': 15100.0,
#     'new_vaccinations': 3283.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-02-03',
#     'total_cases': 221266.0,
#     'new_cases': 719.0,
#     'total_deaths': 9218.0,
#     'new_deaths': 40.0,
#     'total_tests': 1414581.0,
#     'positive_rate': 0.062,
#     'total_vaccinations': 50124.0,
#     'people_vaccinated': 33691.0,
#     'people_fully_vaccinated': 16433.0,
#     'new_vaccinations': 4207.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-02-04',
#     'total_cases': 222149.0,
#     'new_cases': 883.0,
#     'total_deaths': 9272.0,
#     'new_deaths': 54.0,
#     'total_tests': 1424456.0,
#     'positive_rate': 0.07,
#     'total_vaccinations': 54025.0,
#     'people_vaccinated': 36929.0,
#     'people_fully_vaccinated': 17096.0,
#     'new_vaccinations': 3901.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'BGR',
#     'continent': 'Europe',
#     'location': 'Bulgaria',
#     'date': '2021-02-05',
#     'total_cases': 223059.0,
#     'new_cases': 910.0,
#     'total_deaths': 9302.0,
#     'new_deaths': 30.0,
#     'total_tests': 1434996.0,
#     'positive_rate': 0.075,
#     'total_vaccinations': 56860.0,
#     'people_vaccinated': 39468.0,
#     'people_fully_vaccinated': 17392.0,
#     'new_vaccinations': 2835.0,
#     'population': 6948445.0,
#     'median_age': 44.7,
#     'aged_65_older': 20.801,
#     'aged_70_older': 13.272},
#    'geometry': {'type': 'Point', 'coordinates': [25.48583, 42.733883]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-14',
#     'total_cases': 656712.0,
#     'new_cases': 4187.0,
#     'total_deaths': 17294.0,
#     'new_deaths': 90.0,
#     'total_tests': 7076660.0,
#     'positive_rate': 0.079,
#     'total_vaccinations': 18526.0,
#     'people_vaccinated': 12787.0,
#     'people_fully_vaccinated': 5739.0,
#     'new_vaccinations': 3914.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-15',
#     'total_cases': 661180.0,
#     'new_cases': 4468.0,
#     'total_deaths': 17369.0,
#     'new_deaths': 75.0,
#     'total_tests': 7135637.0,
#     'positive_rate': 0.079,
#     'total_vaccinations': 21876.0,
#     'people_vaccinated': 13755.0,
#     'people_fully_vaccinated': 8121.0,
#     'new_vaccinations': 3350.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-16',
#     'total_cases': 665493.0,
#     'new_cases': 4313.0,
#     'total_deaths': 17435.0,
#     'new_deaths': 66.0,
#     'total_tests': 7200836.0,
#     'positive_rate': 0.078,
#     'total_vaccinations': 21937.0,
#     'people_vaccinated': 13766.0,
#     'people_fully_vaccinated': 8171.0,
#     'new_vaccinations': 61.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-17',
#     'total_cases': 669832.0,
#     'new_cases': 4339.0,
#     'total_deaths': 17477.0,
#     'new_deaths': 42.0,
#     'total_tests': 7269294.0,
#     'positive_rate': 0.079,
#     'total_vaccinations': 21972.0,
#     'people_vaccinated': 13781.0,
#     'people_fully_vaccinated': 8191.0,
#     'new_vaccinations': 35.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-18',
#     'total_cases': 673750.0,
#     'new_cases': 3918.0,
#     'total_deaths': 17547.0,
#     'new_deaths': 70.0,
#     'total_tests': 7324967.0,
#     'positive_rate': 0.079,
#     'total_vaccinations': 32385.0,
#     'people_vaccinated': 24025.0,
#     'people_fully_vaccinated': 8360.0,
#     'new_vaccinations': 10413.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-19',
#     'total_cases': 677151.0,
#     'new_cases': 3401.0,
#     'total_deaths': 17573.0,
#     'new_deaths': 26.0,
#     'total_tests': 7366980.0,
#     'positive_rate': 0.081,
#     'total_vaccinations': 50924.0,
#     'people_vaccinated': 42564.0,
#     'people_fully_vaccinated': 8360.0,
#     'new_vaccinations': 18539.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-20',
#     'total_cases': 680740.0,
#     'new_cases': 3589.0,
#     'total_deaths': 17594.0,
#     'new_deaths': 21.0,
#     'total_tests': 7408484.0,
#     'positive_rate': 0.08199999999999999,
#     'total_vaccinations': 54036.0,
#     'people_vaccinated': 45676.0,
#     'people_fully_vaccinated': 8360.0,
#     'new_vaccinations': 3112.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-21',
#     'total_cases': 685107.0,
#     'new_cases': 4367.0,
#     'total_deaths': 17702.0,
#     'new_deaths': 108.0,
#     'total_tests': 7465412.0,
#     'positive_rate': 0.084,
#     'total_vaccinations': 62822.0,
#     'people_vaccinated': 54458.0,
#     'people_fully_vaccinated': 8364.0,
#     'new_vaccinations': 8786.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-22',
#     'total_cases': 690066.0,
#     'new_cases': 4959.0,
#     'total_deaths': 17786.0,
#     'new_deaths': 84.0,
#     'total_tests': 7527928.0,
#     'positive_rate': 0.084,
#     'total_vaccinations': 63047.0,
#     'people_vaccinated': 54683.0,
#     'people_fully_vaccinated': 8364.0,
#     'new_vaccinations': 225.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-23',
#     'total_cases': 694647.0,
#     'new_cases': 4581.0,
#     'total_deaths': 17854.0,
#     'new_deaths': 68.0,
#     'total_tests': 7586356.0,
#     'positive_rate': 0.084,
#     'total_vaccinations': 63939.0,
#     'people_vaccinated': 55575.0,
#     'people_fully_vaccinated': 8364.0,
#     'new_vaccinations': 892.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-26',
#     'total_cases': 706500.0,
#     'new_cases': 3322.0,
#     'total_deaths': 18023.0,
#     'new_deaths': 24.0,
#     'total_tests': 7750080.0,
#     'positive_rate': 0.083,
#     'total_vaccinations': 66569.0,
#     'people_vaccinated': 56551.0,
#     'people_fully_vaccinated': 10018.0,
#     'new_vaccinations': 2283.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-27',
#     'total_cases': 709888.0,
#     'new_cases': 3388.0,
#     'total_deaths': 18040.0,
#     'new_deaths': 17.0,
#     'total_tests': 7789635.0,
#     'positive_rate': 0.08199999999999999,
#     'total_vaccinations': 67096.0,
#     'people_vaccinated': 56764.0,
#     'people_fully_vaccinated': 10332.0,
#     'new_vaccinations': 527.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-28',
#     'total_cases': 714143.0,
#     'new_cases': 4255.0,
#     'total_deaths': 18174.0,
#     'new_deaths': 134.0,
#     'total_tests': 7843425.0,
#     'positive_rate': 0.081,
#     'total_vaccinations': 67111.0,
#     'people_vaccinated': 56764.0,
#     'people_fully_vaccinated': 10347.0,
#     'new_vaccinations': 15.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'CHL',
#     'continent': 'South America',
#     'location': 'Chile',
#     'date': '2021-01-29',
#     'total_cases': 718749.0,
#     'new_cases': 4606.0,
#     'total_deaths': 18257.0,
#     'new_deaths': 83.0,
#     'total_tests': 7905366.0,
#     'positive_rate': 0.079,
#     'total_vaccinations': 67115.0,
#     'people_vaccinated': 56768.0,
#     'people_fully_vaccinated': 10347.0,
#     'new_vaccinations': 4.0,
#     'population': 19116209.0,
#     'median_age': 35.4,
#     'aged_65_older': 11.087,
#     'aged_70_older': 6.938},
#    'geometry': {'type': 'Point',
#     'coordinates': [-71.542969, -35.675146999999996]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-15',
#     'total_cases': 187998.0,
#     'new_cases': 2162.0,
#     'total_deaths': 1721.0,
#     'new_deaths': 60.0,
#     'total_tests': 11699973.0,
#     'positive_rate': 0.016,
#     'total_vaccinations': 166007.0,
#     'people_vaccinated': 166002.0,
#     'people_fully_vaccinated': 5.0,
#     'new_vaccinations': 15255.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-16',
#     'total_cases': 188878.0,
#     'new_cases': 880.0,
#     'total_deaths': 1748.0,
#     'new_deaths': 27.0,
#     'total_tests': 11777255.0,
#     'positive_rate': 0.013999999999999999,
#     'total_vaccinations': 170636.0,
#     'people_vaccinated': 170624.0,
#     'people_fully_vaccinated': 12.0,
#     'new_vaccinations': 4629.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-17',
#     'total_cases': 189767.0,
#     'new_cases': 889.0,
#     'total_deaths': 1776.0,
#     'new_deaths': 28.0,
#     'total_tests': 11852421.0,
#     'positive_rate': 0.013000000000000001,
#     'total_vaccinations': 173903.0,
#     'people_vaccinated': 173165.0,
#     'people_fully_vaccinated': 738.0,
#     'new_vaccinations': 3267.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-18',
#     'total_cases': 190574.0,
#     'new_cases': 807.0,
#     'total_deaths': 1806.0,
#     'new_deaths': 30.0,
#     'total_tests': 11963177.0,
#     'positive_rate': 0.011000000000000001,
#     'total_vaccinations': 179946.0,
#     'people_vaccinated': 177046.0,
#     'people_fully_vaccinated': 2900.0,
#     'new_vaccinations': 6043.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-19',
#     'total_cases': 191299.0,
#     'new_cases': 725.0,
#     'total_deaths': 1838.0,
#     'new_deaths': 32.0,
#     'total_tests': 12087645.0,
#     'positive_rate': 0.01,
#     'total_vaccinations': 184564.0,
#     'people_vaccinated': 179537.0,
#     'people_fully_vaccinated': 5027.0,
#     'new_vaccinations': 4618.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-20',
#     'total_cases': 192187.0,
#     'new_cases': 888.0,
#     'total_deaths': 1873.0,
#     'new_deaths': 35.0,
#     'total_tests': 12203828.0,
#     'positive_rate': 0.009000000000000001,
#     'total_vaccinations': 187999.0,
#     'people_vaccinated': 181057.0,
#     'people_fully_vaccinated': 6942.0,
#     'new_vaccinations': 3435.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-21',
#     'total_cases': 192947.0,
#     'new_cases': 760.0,
#     'total_deaths': 1910.0,
#     'new_deaths': 37.0,
#     'total_tests': 12330219.0,
#     'positive_rate': 0.01,
#     'total_vaccinations': 191911.0,
#     'people_vaccinated': 182586.0,
#     'people_fully_vaccinated': 9325.0,
#     'new_vaccinations': 3912.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-22',
#     'total_cases': 193720.0,
#     'new_cases': 773.0,
#     'total_deaths': 1942.0,
#     'new_deaths': 32.0,
#     'total_tests': 12443037.0,
#     'positive_rate': 0.008,
#     'total_vaccinations': 198298.0,
#     'people_vaccinated': 183245.0,
#     'people_fully_vaccinated': 15053.0,
#     'new_vaccinations': 6387.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-23',
#     'total_cases': 194599.0,
#     'new_cases': 879.0,
#     'total_deaths': 1970.0,
#     'new_deaths': 28.0,
#     'total_tests': 12524740.0,
#     'positive_rate': 0.008,
#     'total_vaccinations': 206259.0,
#     'people_vaccinated': 184029.0,
#     'people_fully_vaccinated': 22230.0,
#     'new_vaccinations': 7961.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-24',
#     'total_cases': 195353.0,
#     'new_cases': 754.0,
#     'total_deaths': 1984.0,
#     'new_deaths': 14.0,
#     'total_tests': 12604711.0,
#     'positive_rate': 0.006999999999999999,
#     'total_vaccinations': 213533.0,
#     'people_vaccinated': 184646.0,
#     'people_fully_vaccinated': 28887.0,
#     'new_vaccinations': 7274.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-25',
#     'total_cases': 195978.0,
#     'new_cases': 625.0,
#     'total_deaths': 2011.0,
#     'new_deaths': 27.0,
#     'total_tests': 12731012.0,
#     'positive_rate': 0.006999999999999999,
#     'total_vaccinations': 216251.0,
#     'people_vaccinated': 184892.0,
#     'people_fully_vaccinated': 31359.0,
#     'new_vaccinations': 2718.0,
#     'population': 5792203.0,
#     'median_age': 42.3,
#     'aged_65_older': 19.677,
#     'aged_70_older': 12.325},
#    'geometry': {'type': 'Point', 'coordinates': [9.501785, 56.26392]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'DNK',
#     'continent': 'Europe',
#     'location': 'Denmark',
#     'date': '2021-01-26',
#     'total_cases': 196632.0,
#     'new_cases': 654.0,
#     'total_deaths': 2031.0,
#     'new_deaths': 20.0,
# ...
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-13',
#     'total_cases': 3220953.0,
#     'new_cases': 47662.0,
#     'total_deaths': 84910.0,
#     'new_deaths': 1568.0,
#     'total_tests': 59538320.0,
#     'positive_rate': 0.09,
#     'total_vaccinations': 3356229.0,
#     'people_vaccinated': 2918252.0,
#     'people_fully_vaccinated': 437977.0,
#     'new_vaccinations': 288688.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-14',
#     'total_cases': 3269757.0,
#     'new_cases': 48804.0,
#     'total_deaths': 86163.0,
#     'new_deaths': 1253.0,
#     'total_tests': 60242686.0,
#     'positive_rate': 0.08800000000000001,
#     'total_vaccinations': 3678180.0,
#     'people_vaccinated': 3234946.0,
#     'people_fully_vaccinated': 443234.0,
#     'new_vaccinations': 321951.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-15',
#     'total_cases': 3325642.0,
#     'new_cases': 55885.0,
#     'total_deaths': 87448.0,
#     'new_deaths': 1285.0,
#     'total_tests': 60848505.0,
#     'positive_rate': 0.086,
#     'total_vaccinations': 4006440.0,
#     'people_vaccinated': 3559179.0,
#     'people_fully_vaccinated': 447261.0,
#     'new_vaccinations': 328260.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-16',
#     'total_cases': 3367070.0,
#     'new_cases': 41428.0,
#     'total_deaths': 88747.0,
#     'new_deaths': 1299.0,
#     'total_tests': 61349606.0,
#     'positive_rate': 0.083,
#     'total_vaccinations': 4286830.0,
#     'people_vaccinated': 3837094.0,
#     'people_fully_vaccinated': 449736.0,
#     'new_vaccinations': 280390.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-17',
#     'total_cases': 3405740.0,
#     'new_cases': 38670.0,
#     'total_deaths': 89429.0,
#     'new_deaths': 682.0,
#     'total_tests': 61774304.0,
#     'positive_rate': 0.081,
#     'total_vaccinations': 4514802.0,
#     'people_vaccinated': 4062501.0,
#     'people_fully_vaccinated': 452301.0,
#     'new_vaccinations': 227972.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-18',
#     'total_cases': 3443350.0,
#     'new_cases': 37610.0,
#     'total_deaths': 90031.0,
#     'new_deaths': 602.0,
#     'total_tests': 62357805.0,
#     'positive_rate': 0.078,
#     'total_vaccinations': 4723443.0,
#     'people_vaccinated': 4266577.0,
#     'people_fully_vaccinated': 456866.0,
#     'new_vaccinations': 208641.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-19',
#     'total_cases': 3476804.0,
#     'new_cases': 33454.0,
#     'total_deaths': 91643.0,
#     'new_deaths': 1612.0,
#     'total_tests': 62956912.0,
#     'positive_rate': 0.075,
#     'total_vaccinations': 5070365.0,
#     'people_vaccinated': 4609740.0,
#     'people_fully_vaccinated': 460625.0,
#     'new_vaccinations': 346922.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-20',
#     'total_cases': 3515796.0,
#     'new_cases': 38992.0,
#     'total_deaths': 93469.0,
#     'new_deaths': 1826.0,
#     'total_tests': 63623219.0,
#     'positive_rate': 0.07200000000000001,
#     'total_vaccinations': 5437284.0,
#     'people_vaccinated': 4973248.0,
#     'people_fully_vaccinated': 464036.0,
#     'new_vaccinations': 366919.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-21',
#     'total_cases': 3553773.0,
#     'new_cases': 37977.0,
#     'total_deaths': 94765.0,
#     'new_deaths': 1296.0,
#     'total_tests': 64303048.0,
#     'positive_rate': 0.07,
#     'total_vaccinations': 5849899.0,
#     'people_vaccinated': 5383103.0,
#     'people_fully_vaccinated': 466796.0,
#     'new_vaccinations': 412615.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-22',
#     'total_cases': 3594094.0,
#     'new_cases': 40321.0,
#     'total_deaths': 96166.0,
#     'new_deaths': 1401.0,
#     'total_tests': 64951149.0,
#     'positive_rate': 0.065,
#     'total_vaccinations': 6329968.0,
#     'people_vaccinated': 5861351.0,
#     'people_fully_vaccinated': 468617.0,
#     'new_vaccinations': 480069.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-23',
#     'total_cases': 3627746.0,
#     'new_cases': 33652.0,
#     'total_deaths': 97518.0,
#     'new_deaths': 1352.0,
#     'total_tests': 65442601.0,
#     'positive_rate': 0.064,
#     'total_vaccinations': 6822981.0,
#     'people_vaccinated': 6353321.0,
#     'people_fully_vaccinated': 469660.0,
#     'new_vaccinations': 493013.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-24',
#     'total_cases': 3657857.0,
#     'new_cases': 30111.0,
#     'total_deaths': 98129.0,
#     'new_deaths': 611.0,
#     'total_tests': 65861305.0,
#     'positive_rate': 0.062,
#     'total_vaccinations': 7044048.0,
#     'people_vaccinated': 6573570.0,
#     'people_fully_vaccinated': 470478.0,
#     'new_vaccinations': 221067.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-25',
#     'total_cases': 3680101.0,
#     'new_cases': 22244.0,
#     'total_deaths': 98723.0,
#     'new_deaths': 594.0,
#     'total_tests': 66422967.0,
#     'positive_rate': 0.057999999999999996,
#     'total_vaccinations': 7325773.0,
#     'people_vaccinated': 6853327.0,
#     'people_fully_vaccinated': 472446.0,
#     'new_vaccinations': 281725.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-26',
#     'total_cases': 3700268.0,
#     'new_cases': 20167.0,
#     'total_deaths': 100359.0,
#     'new_deaths': 1636.0,
#     'total_tests': 67040373.0,
#     'positive_rate': 0.055,
#     'total_vaccinations': 7638543.0,
#     'people_vaccinated': 7164387.0,
#     'people_fully_vaccinated': 474156.0,
#     'new_vaccinations': 312770.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-27',
#     'total_cases': 3725637.0,
#     'new_cases': 25369.0,
#     'total_deaths': 102085.0,
#     'new_deaths': 1726.0,
#     'total_tests': 67828936.0,
#     'positive_rate': 0.05,
#     'total_vaccinations': 7953250.0,
#     'people_vaccinated': 7476765.0,
#     'people_fully_vaccinated': 476485.0,
#     'new_vaccinations': 314707.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-28',
#     'total_cases': 3754448.0,
#     'new_cases': 28811.0,
#     'total_deaths': 103324.0,
#     'new_deaths': 1239.0,
#     'total_tests': 68606924.0,
#     'positive_rate': 0.047,
#     'total_vaccinations': 8369438.0,
#     'people_vaccinated': 7891184.0,
#     'people_fully_vaccinated': 478254.0,
#     'new_vaccinations': 416188.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-29',
#     'total_cases': 3783593.0,
#     'new_cases': 29145.0,
#     'total_deaths': 104572.0,
#     'new_deaths': 1248.0,
#     'total_tests': 69288509.0,
#     'positive_rate': 0.044000000000000004,
#     'total_vaccinations': 8859372.0,
#     'people_vaccinated': 8378940.0,
#     'people_fully_vaccinated': 480432.0,
#     'new_vaccinations': 489934.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-30',
#     'total_cases': 3806993.0,
#     'new_cases': 23400.0,
#     'total_deaths': 105777.0,
#     'new_deaths': 1205.0,
#     'total_tests': 69736280.0,
#     'positive_rate': 0.042,
#     'total_vaccinations': 9468382.0,
#     'people_vaccinated': 8977329.0,
#     'people_fully_vaccinated': 491053.0,
#     'new_vaccinations': 609010.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-01-31',
#     'total_cases': 3828183.0,
#     'new_cases': 21190.0,
#     'total_deaths': 106367.0,
#     'new_deaths': 590.0,
#     'total_tests': 70340312.0,
#     'positive_rate': 0.038,
#     'total_vaccinations': 9790576.0,
#     'people_vaccinated': 9296367.0,
#     'people_fully_vaccinated': 494209.0,
#     'new_vaccinations': 322194.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-02-01',
#     'total_cases': 3846851.0,
#     'new_cases': 18668.0,
#     'total_deaths': 106774.0,
#     'new_deaths': 407.0,
#     'total_tests': 71011933.0,
#     'positive_rate': 0.036000000000000004,
#     'total_vaccinations': 10143511.0,
#     'people_vaccinated': 9646715.0,
#     'people_fully_vaccinated': 496796.0,
#     'new_vaccinations': 352935.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-02-02',
#     'total_cases': 3863757.0,
#     'new_cases': 16906.0,
#     'total_deaths': 108225.0,
#     'new_deaths': 1451.0,
#     'total_tests': 71642534.0,
#     'positive_rate': 0.036000000000000004,
#     'total_vaccinations': 10520433.0,
#     'people_vaccinated': 10021471.0,
#     'people_fully_vaccinated': 498962.0,
#     'new_vaccinations': 376922.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-02-03',
#     'total_cases': 3882972.0,
#     'new_cases': 19215.0,
#     'total_deaths': 109547.0,
#     'new_deaths': 1322.0,
#     'total_tests': 72464146.0,
#     'positive_rate': 0.034,
#     'total_vaccinations': 10992444.0,
#     'people_vaccinated': 10490487.0,
#     'people_fully_vaccinated': 501957.0,
#     'new_vaccinations': 472011.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'GBR',
#     'continent': 'Europe',
#     'location': 'United Kingdom',
#     'date': '2021-02-04',
#     'total_cases': 3903706.0,
#     'new_cases': 20734.0,
#     'total_deaths': 110462.0,
#     'new_deaths': 915.0,
#     'total_tests': 73277874.0,
#     'positive_rate': 0.032,
#     'total_vaccinations': 11477040.0,
#     'people_vaccinated': 10971047.0,
#     'people_fully_vaccinated': 505993.0,
#     'new_vaccinations': 484596.0,
#     'population': 67886004.0,
#     'median_age': 40.8,
#     'aged_65_older': 18.517,
#     'aged_70_older': 12.527000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-3.435973, 55.378051]}},
#   {'type': 'Feature',
#    'properties': {'iso_code': 'USA',
#     'continent': 'North America',
#     'location': 'United States',
#     'date': '2021-01-25',
#     'total_cases': 25298986.0,
#     'new_cases': 151095.0,
#     'total_deaths': 422477.0,
#     'new_deaths': 1946.0,
#     'total_tests': 291411859.0,
#     'positive_rate': 0.09699999999999999,
#     'total_vaccinations': 22734243.0,
#     'people_vaccinated': 19252279.0,
#     'people_fully_vaccinated': 3346390.0,
#     'new_vaccinations': 885588.0,
#     'population': 331002647.0,
#     'median_age': 38.3,
#     'aged_65_older': 15.413,
#     'aged_70_older': 9.732000000000001},
#    'geometry': {'type': 'Point', 'coordinates': [-95.712891, 37.09024]}}]}

# %%
import json

output_filename = 'dataset.geojson'
with open(output_filename, 'w') as output_file:
    output_file.write('var dataset = ')
    json.dump(geojson, output_file, indent=2)

# %% [markdown]
# ### Export Cleaned Datasets to SQLite

# %%
## Create the connection using the imported create_engine function and then invoking the connect method on it
engine = create_engine('sqlite:///VAERS.db', echo=False)
sqlite_connection = engine.connect()

# %%
## Set a variable name with the string of a table name
sqlite_vaers = "2021VAERS"
merge_all.to_sql(sqlite_vaers, sqlite_connection, if_exists='fail')

# %%
## Close the database connection 
sqlite_connection.close()

# %%
## Create the connection using the imported create_engine function and then invoking the connect method on it
engine = create_engine('sqlite:///worldWideData.db', echo=False)
sqlite_connection = engine.connect()

# %%
## Set a variable name with the string of a table name
sqlite_worldWideData = "worldWideData"
wanted_columns4.to_sql(sqlite_worldWideData, sqlite_connection, if_exists='fail')

# %%
## Close the database connection 
sqlite_connection.close()
