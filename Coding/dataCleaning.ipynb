# %% [markdown]
# ## Filtering and Merging 2021VAERS Datasets & Filtering Global Vaccination Dataset

# %%
# Import dependencies
import pandas as pd

from sqlalchemy import create_engine

# %% [markdown]
# ### 2021 VAERS Datasets-Data Filtering and Cleaning

# %% [markdown]
# #### 2021VAERSVAX.csv: Filter the data based on vaccination type = COVID19,  and remove unneeded columns

# %%
# Import data file
VAERSvax = "dataUsed/2021VAERSVAX.csv"

# Read data file, need the encoding to read properly
VAERSvax_raw = pd.read_csv(VAERSvax, encoding="ISO-8859-1")
VAERSvax_raw
# Out:
#       VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0       916710  COVID19          MODERNA      NaN               1        IM
# 1       916741  COVID19  PFIZER\BIONTECH   EH9899               1       SYR
# 2       916742  COVID19  PFIZER\BIONTECH      NaN               1        IM
# 3       916746  COVID19          MODERNA  037K20A               1        IM
# 4       916772  COVID19  PFIZER\BIONTECH   EJ1685             UNK        IM
# ...        ...      ...              ...      ...             ...       ...
# 3009    983720  COVID19          MODERNA  039K20A               1        IM
# 3010    983721  COVID19          MODERNA  039K20A               1        IM
# 3011    983766  COVID19          MODERNA  013L20A               1        IM
# 3012    983919  COVID19          MODERNA  030L20A               1        IM
# 3013    985205  COVID19          MODERNA  029L20A               1        IM
#
#      VAX_SITE                             VAX_NAME
# 0          LA          COVID19 (COVID19 (MODERNA))
# 1          LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2         NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3          LA          COVID19 (COVID19 (MODERNA))
# 4          LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# ...       ...                                  ...
# 3009       LA          COVID19 (COVID19 (MODERNA))
# 3010       RA          COVID19 (COVID19 (MODERNA))
# 3011       RA          COVID19 (COVID19 (MODERNA))
# 3012       LA          COVID19 (COVID19 (MODERNA))
# 3013       UN          COVID19 (COVID19 (MODERNA))
#
# [3014 rows x 8 columns]

# %%
# Extract the columns names
columns = list(VAERSvax_raw.columns)
columns
# Out:
# ['VAERS_ID',
#  'VAX_TYPE',
#  'VAX_MANU',
#  'VAX_LOT',
#  'VAX_DOSE_SERIES',
#  'VAX_ROUTE',
#  'VAX_SITE',
#  'VAX_NAME']

# %%
# Create a dataframe with the wanted columns only
wanted_columns = VAERSvax_raw[['VAERS_ID',
 'VAX_TYPE',
 'VAX_MANU',
 'VAX_DOSE_SERIES',
 'VAX_SITE'
]]
wanted_columns
# Out:
#       VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 0       916710  COVID19          MODERNA               1       LA
# 1       916741  COVID19  PFIZER\BIONTECH               1       LA
# 2       916742  COVID19  PFIZER\BIONTECH               1      NaN
# 3       916746  COVID19          MODERNA               1       LA
# 4       916772  COVID19  PFIZER\BIONTECH             UNK       LA
# ...        ...      ...              ...             ...      ...
# 3009    983720  COVID19          MODERNA               1       LA
# 3010    983721  COVID19          MODERNA               1       RA
# 3011    983766  COVID19          MODERNA               1       RA
# 3012    983919  COVID19          MODERNA               1       LA
# 3013    985205  COVID19          MODERNA               1       UN
#
# [3014 rows x 5 columns]

# %%
# Filter the data by vax_type = COVID19
# Reset index
filtered_data = wanted_columns[wanted_columns["VAX_TYPE"]=="COVID19"]
filtered_data.reset_index(drop=True, inplace=True)
filtered_data
# Out:
#       VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 0       916710  COVID19          MODERNA               1       LA
# 1       916741  COVID19  PFIZER\BIONTECH               1       LA
# 2       916742  COVID19  PFIZER\BIONTECH               1      NaN
# 3       916746  COVID19          MODERNA               1       LA
# 4       916772  COVID19  PFIZER\BIONTECH             UNK       LA
# ...        ...      ...              ...             ...      ...
# 2839    983720  COVID19          MODERNA               1       LA
# 2840    983721  COVID19          MODERNA               1       RA
# 2841    983766  COVID19          MODERNA               1       RA
# 2842    983919  COVID19          MODERNA               1       LA
# 2843    985205  COVID19          MODERNA               1       UN
#
# [2844 rows x 5 columns]

# %% [markdown]
# #### 2021VAERSData.csv

# %%
# Import data file
VAERSData = "dataUsed/2021VAERSData.csv"

# Read data file, need the encoding to read properly
vaer_data_raw = pd.read_csv(VAERSData, encoding="ISO-8859-1")
vaer_data_raw
# Out:
#       VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0       916710  01/01/2021    MO     23.0     23.0      NaN   F      NaN
# 1       916741  01/01/2021    AR     68.0     68.0      NaN   F      NaN
# 2       916742  01/01/2021    MN     29.0     29.0      NaN   F      NaN
# 3       916746  01/01/2021    TX     49.0     49.0      NaN   F      NaN
# 4       916772  01/01/2021    GA     55.0     55.0      NaN   M      NaN
# ...        ...         ...   ...      ...      ...      ...  ..      ...
# 2941    983428  01/28/2021    NE     68.0     68.0      NaN   F      NaN
# 2942    983482  01/28/2021    CA     90.0     90.0      NaN   M      NaN
# 2943    983766  01/28/2021    NC     90.0     90.0      NaN   F      NaN
# 2944    983919  01/28/2021    FL     69.0     69.0      NaN   M      NaN
# 2945    985205  01/29/2021    OH     75.0     75.0      NaN   M      NaN
#
#                                            SYMPTOM_TEXT DIED  ...  \
# 0     Acute appendicitis, onset morning of 1/1/2021 ...  NaN  ...
# 1     on dec 22 I felt some myalgias, chills, fatigu...  NaN  ...
# 2     Within 15 minutes of receiving the vaccine I b...  NaN  ...
# 3     Anaphylaxis. Immediately experienced shortness...  NaN  ...
# 4     Vaccine on 12/22/2020 and started feeling bad ...  NaN  ...
# ...                                                 ...  ...  ...
# 2941  Pt. was admitted to hospital on 1/6/21 with fa...    Y  ...
# 2942  per daughter pt suffered a stroke 1 hour after...    Y  ...
# 2943  Pt started complaining of chest heaviness and ...    Y  ...
# 2944                                              death    Y  ...
# 2945  Patient was feeling dizzy and under the weathe...    Y  ...
#
#                                                 CUR_ILL  \
# 0                                                   NaN
# 1     had surgery R hand for advanced arthritis 11/1...
# 2                                                  None
# 3                                                  None
# 4                                                   NaN
# ...                                                 ...
# 2941  Denied any illness at time of the vaccination....
# 2942                                                NaN
# 2943  Heart failure with reduced EF, history of mode...
# 2944                                                NaN
# 2945                                                 No
#
#                                                 HISTORY  PRIOR_VAX SPLTTYPE  \
# 0                                        Hypothyroidism        NaN      NaN
# 1     Rheumatoid arthritis - mostly affecting R wris...        NaN      NaN
# 2                                 Sports induced asthma        NaN      NaN
# 3                                                  None        NaN      NaN
# 4                       HTN, Insomnia,High Cholesterol,        NaN      NaN
# ...                                                 ...        ...      ...
# 2941  Erysipelas, Aphthous pharyngitis, Sixth nerve ...        NaN      NaN
# 2942  Prostate cancer (HCC)   Nervous and Auditory N...        NaN      NaN
# 2943  Heart failure with reduced EF, history of mode...        NaN      NaN
# 2944                                                NaN        NaN      NaN
# 2945                                               None        NaN      NaN
#
#       FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT  \
# 0             2  01/01/2021          NaN       NaN           Y
# 1             2  01/01/2021          NaN       NaN         NaN
# 2             2  01/01/2021          NaN         Y           Y
# 3             2  01/01/2021          NaN       NaN           Y
# 4             2  01/01/2021          NaN         Y         NaN
# ...         ...         ...          ...       ...         ...
# 2941          2  01/28/2021          NaN       NaN           Y
# 2942          2  01/28/2021          NaN       NaN         NaN
# 2943          2  01/28/2021          NaN       NaN           Y
# 2944          2  01/28/2021          NaN       NaN         NaN
# 2945          2  01/29/2021          NaN       NaN         NaN
#
#                                               ALLERGIES
# 0                                                  NKDA
# 1                                            bee stings
# 2     Amoxicillin, penicillin, oxycodone, roxicodone...
# 3                                     Shellfish, Iodine
# 4                                               Codeine
# ...                                                 ...
# 2941                                 NKA to medications
# 2942                                 lisinopril, nsaids
# 2943                No known allergies to drugs or food
# 2944                                                NaN
# 2945                                                 No
#
# [2946 rows x 35 columns]

# %% [markdown]
# #### 2021VAERSSymptoms.csv

# %%
# Import data file
VAERSsymptoms = "dataUsed/2021VAERSSYMPTOMS.csv"

# Read data file, need the encoding to read properly
vaer_symptoms_raw = pd.read_csv(VAERSsymptoms, encoding="ISO-8859-1")
vaer_symptoms_raw
# Out:
#       VAERS_ID                                  SYMPTOM1  SYMPTOMVERSION1  \
# 0       916710                              Appendicitis             23.1
# 1       916741                                    Chills             23.1
# 2       916741                                   Myalgia             23.1
# 3       916742                     Anaphylactic reaction             23.1
# 4       916742                            Intensive care             23.1
# ...        ...                                       ...              ...
# 4707    983721                                     Death             23.1
# 4708    983766                        Blood pH decreased             23.1
# 4709    983766  International normalised ratio increased             23.1
# 4710    983919                                     Death             23.1
# 4711    985205                                     Death             23.1
#
#                                                SYMPTOM2  SYMPTOMVERSION2  \
# 0                  Band neutrophil percentage increased             23.1
# 1                        Complex regional pain syndrome             23.1
# 2                                     Pain in extremity             23.1
# 3                                            Blood test             23.1
# 4                                              Pruritus             23.1
# ...                                                 ...              ...
# 4707                                                NaN              NaN
# 4708                              Cardiac failure acute             23.1
# 4709  N-terminal prohormone brain natriuretic peptid...             23.1
# 4710                                                NaN              NaN
# 4711                                          Dizziness             23.1
#
#                       SYMPTOM3  SYMPTOMVERSION3  \
# 0                      Surgery             23.1
# 1                      Fatigue             23.1
# 2          Peripheral swelling             23.1
# 3            Burning sensation             23.1
# 4                         Rash             23.1
# ...                        ...              ...
# 4707                       NaN              NaN
# 4708          Chest discomfort             23.1
# 4709  SARS-CoV-2 test negative             23.1
# 4710                       NaN              NaN
# 4711                   Malaise             23.1
#
#                               SYMPTOM4  SYMPTOMVERSION4  \
# 0     White blood cell count increased             23.1
# 1                             Headache             23.1
# 2                       X-ray abnormal             23.1
# 3       Central venous catheterisation             23.1
# 4                         Rash macular             23.1
# ...                                ...              ...
# 4707                               NaN              NaN
# 4708                             Death             23.1
# 4709                               NaN              NaN
# 4710                               NaN              NaN
# 4711                               NaN              NaN
#
#                              SYMPTOM5  SYMPTOMVERSION5
# 0                                 NaN              NaN
# 1     Joint range of motion decreased             23.1
# 2                                 NaN              NaN
# 3                           Dysphonia             23.1
# 4                    Throat tightness             23.1
# ...                               ...              ...
# 4707                              NaN              NaN
# 4708                         Dyspnoea             23.1
# 4709                              NaN              NaN
# 4710                              NaN              NaN
# 4711                              NaN              NaN
#
# [4712 rows x 11 columns]

# %% [markdown]
# ### World Wide Dataset-Data Cleaning

# %%
# Import data file
worldWideData = "dataUsed/WorldWideData.csv"

# Read data file, need the encoding to read properly
world_raw = pd.read_csv(worldWideData, encoding="ISO-8859-1")
world_raw
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 67890      ZWE    Africa     Zimbabwe  2021-02-05      34331.0      160.0
# 67891      ZWE    Africa     Zimbabwe  2021-02-06      34487.0      156.0
# 67892      ZWE    Africa     Zimbabwe  2021-02-07      34552.0       65.0
# 67893      ZWE    Africa     Zimbabwe  2021-02-08      34658.0      106.0
# 67894      ZWE    Africa     Zimbabwe  2021-02-09      34781.0      123.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 67890             197.000        1303.0        15.0               17.857  ...
# 67891             173.429        1316.0        13.0               17.571  ...
# 67892             166.286        1326.0        10.0               15.571  ...
# 67893             158.571        1339.0        13.0               15.000  ...
# 67894             138.143        1353.0        14.0               14.143  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 67890        1899.775             21.4                307.846
# 67891        1899.775             21.4                307.846
# 67892        1899.775             21.4                307.846
# 67893        1899.775             21.4                307.846
# 67894        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 67890                 1.82             1.6          30.7
# 67891                 1.82             1.6          30.7
# 67892                 1.82             1.6          30.7
# 67893                 1.82             1.6          30.7
# 67894                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 67890                  36.791                         1.7            61.49
# 67891                  36.791                         1.7            61.49
# 67892                  36.791                         1.7            61.49
# 67893                  36.791                         1.7            61.49
# 67894                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 67890                    0.571
# 67891                    0.571
# 67892                    0.571
# 67893                    0.571
# 67894                    0.571
#
# [67895 rows x 59 columns]
