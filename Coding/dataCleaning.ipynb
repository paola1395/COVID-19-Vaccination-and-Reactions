# %% [markdown]
# ## Filtering and Merging 2021VAERS Datasets & Filtering Global Vaccination Dataset

# %%
# Import dependencies
import pandas as pd

from sqlalchemy import create_engine

# %% [markdown]
# ### 2021 VAERS Datasets-Data Filtering and Cleaning

# %% [markdown]
# #### 2021VAERSVAX.csv: Filter the data based on vaccination type = COVID19,  and remove unneeded columns

# %%
# Import data file
VAERSvax = "dataUsed/2021VAERSVAX.csv"

# Read data file, need the encoding to read properly
VAERSvax_raw = pd.read_csv(VAERSvax, encoding="ISO-8859-1")
display(VAERSvax_raw.head(5))
display(VAERSvax_raw.tail(5))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    916710  COVID19          MODERNA      NaN               1        IM
# 1    916741  COVID19  PFIZER\BIONTECH   EH9899               1       SYR
# 2    916742  COVID19  PFIZER\BIONTECH      NaN               1        IM
# 3    916746  COVID19          MODERNA  037K20A               1        IM
# 4    916772  COVID19  PFIZER\BIONTECH   EJ1685             UNK        IM
#
#   VAX_SITE                             VAX_NAME
# 0       LA          COVID19 (COVID19 (MODERNA))
# 1       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2      NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3       LA          COVID19 (COVID19 (MODERNA))
# 4       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
#       VAERS_ID VAX_TYPE VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 3009    983720  COVID19  MODERNA  039K20A               1        IM       LA
# 3010    983721  COVID19  MODERNA  039K20A               1        IM       RA
# 3011    983766  COVID19  MODERNA  013L20A               1        IM       RA
# 3012    983919  COVID19  MODERNA  030L20A               1        IM       LA
# 3013    985205  COVID19  MODERNA  029L20A               1        IM       UN
#
#                          VAX_NAME
# 3009  COVID19 (COVID19 (MODERNA))
# 3010  COVID19 (COVID19 (MODERNA))
# 3011  COVID19 (COVID19 (MODERNA))
# 3012  COVID19 (COVID19 (MODERNA))
# 3013  COVID19 (COVID19 (MODERNA))

# %%
# Extract the columns names
columns = list(VAERSvax_raw.columns)
columns
# Out:
# ['VAERS_ID',
#  'VAX_TYPE',
#  'VAX_MANU',
#  'VAX_LOT',
#  'VAX_DOSE_SERIES',
#  'VAX_ROUTE',
#  'VAX_SITE',
#  'VAX_NAME']

# %%
# Create a dataframe with the wanted columns only
wanted_columns = VAERSvax_raw[['VAERS_ID',
 'VAX_TYPE',
 'VAX_MANU',
 'VAX_DOSE_SERIES',
 'VAX_SITE'
]]
display(wanted_columns.head(5))
display(wanted_columns.tail(5))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 0    916710  COVID19          MODERNA               1       LA
# 1    916741  COVID19  PFIZER\BIONTECH               1       LA
# 2    916742  COVID19  PFIZER\BIONTECH               1      NaN
# 3    916746  COVID19          MODERNA               1       LA
# 4    916772  COVID19  PFIZER\BIONTECH             UNK       LA
#       VAERS_ID VAX_TYPE VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 3009    983720  COVID19  MODERNA               1       LA
# 3010    983721  COVID19  MODERNA               1       RA
# 3011    983766  COVID19  MODERNA               1       RA
# 3012    983919  COVID19  MODERNA               1       LA
# 3013    985205  COVID19  MODERNA               1       UN

# %%
# Filter the data by vax_type = COVID19
# Reset index
filtered_data = wanted_columns[wanted_columns["VAX_TYPE"]=="COVID19"]
filtered_data.reset_index(drop=True, inplace=True)
display(filtered_data.head(5))
display(filtered_data.tail(5))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 0    916710  COVID19          MODERNA               1       LA
# 1    916741  COVID19  PFIZER\BIONTECH               1       LA
# 2    916742  COVID19  PFIZER\BIONTECH               1      NaN
# 3    916746  COVID19          MODERNA               1       LA
# 4    916772  COVID19  PFIZER\BIONTECH             UNK       LA
#       VAERS_ID VAX_TYPE VAX_MANU VAX_DOSE_SERIES VAX_SITE
# 2839    983720  COVID19  MODERNA               1       LA
# 2840    983721  COVID19  MODERNA               1       RA
# 2841    983766  COVID19  MODERNA               1       RA
# 2842    983919  COVID19  MODERNA               1       LA
# 2843    985205  COVID19  MODERNA               1       UN

# %% [markdown]
# #### 2021VAERSData.csv

# %%
# Import data file
VAERSData = "dataUsed/2021VAERSData.csv"

# Read data file, need the encoding to read properly
vaer_data_raw = pd.read_csv(VAERSData, encoding="ISO-8859-1")
display(vaer_data_raw.head(2))
display(vaer_data_raw.tail(2))
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916710  01/01/2021    MO     23.0     23.0      NaN   F      NaN
# 1    916741  01/01/2021    AR     68.0     68.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Acute appendicitis, onset morning of 1/1/2021 ...  NaN  ...
# 1  on dec 22 I felt some myalgias, chills, fatigu...  NaN  ...
#
#                                              CUR_ILL  \
# 0                                                NaN
# 1  had surgery R hand for advanced arthritis 11/1...
#
#                                              HISTORY  PRIOR_VAX SPLTTYPE  \
# 0                                     Hypothyroidism        NaN      NaN
# 1  Rheumatoid arthritis - mostly affecting R wris...        NaN      NaN
#
#    FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT   ALLERGIES
# 0          2  01/01/2021          NaN       NaN           Y        NKDA
# 1          2  01/01/2021          NaN       NaN         NaN  bee stings
#
# [2 rows x 35 columns]
#       VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 2944    983919  01/28/2021    FL     69.0     69.0      NaN   M      NaN
# 2945    985205  01/29/2021    OH     75.0     75.0      NaN   M      NaN
#
#                                            SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 2944                                              death    Y  ...     NaN
# 2945  Patient was feeling dizzy and under the weathe...    Y  ...      No
#
#      HISTORY  PRIOR_VAX SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# 2944     NaN        NaN      NaN          2  01/28/2021          NaN
# 2945    None        NaN      NaN          2  01/29/2021          NaN
#
#      OFC_VISIT ER_ED_VISIT ALLERGIES
# 2944       NaN         NaN       NaN
# 2945       NaN         NaN        No
#
# [2 rows x 35 columns]

# %%
# Extract the columns names
columns2 = list(vaer_data_raw.columns)
columns2
# Out:
# ['VAERS_ID',
#  'RECVDATE',
#  'STATE',
#  'AGE_YRS',
#  'CAGE_YR',
#  'CAGE_MO',
#  'SEX',
#  'RPT_DATE',
#  'SYMPTOM_TEXT',
#  'DIED',
#  'DATEDIED',
#  'L_THREAT',
#  'ER_VISIT',
#  'HOSPITAL',
#  'HOSPDAYS',
#  'X_STAY',
#  'DISABLE',
#  'RECOVD',
#  'VAX_DATE',
#  'ONSET_DATE',
#  'NUMDAYS',
#  'LAB_DATA',
#  'V_ADMINBY',
#  'V_FUNDBY',
#  'OTHER_MEDS',
#  'CUR_ILL',
#  'HISTORY',
#  'PRIOR_VAX',
#  'SPLTTYPE',
#  'FORM_VERS',
#  'TODAYS_DATE',
#  'BIRTH_DEFECT',
#  'OFC_VISIT',
#  'ER_ED_VISIT',
#  'ALLERGIES']

# %%
# Create a dataframe with the wanted columns only
wanted_columns2 = vaer_data_raw[['VAERS_ID',
 'STATE',
 'AGE_YRS',
 'SEX',
 'DIED',
 'DATEDIED',
 'L_THREAT',
 'ER_VISIT',
 'HOSPITAL',
 'HOSPDAYS',
 'X_STAY',
 'DISABLE',
 'RECOVD',
 'VAX_DATE',
 'ONSET_DATE',
 'NUMDAYS'
]]
wanted_columns2.head(5)
# Out:
#    VAERS_ID STATE  AGE_YRS SEX DIED DATEDIED L_THREAT  ER_VISIT HOSPITAL  \
# 0    916710    MO     23.0   F  NaN      NaN        Y       NaN        Y
# 1    916741    AR     68.0   F  NaN      NaN      NaN       NaN      NaN
# 2    916742    MN     29.0   F  NaN      NaN        Y       NaN        Y
# 3    916746    TX     49.0   F  NaN      NaN        Y       NaN      NaN
# 4    916772    GA     55.0   M  NaN      NaN      NaN       NaN      NaN
#
#    HOSPDAYS X_STAY DISABLE RECOVD    VAX_DATE  ONSET_DATE  NUMDAYS
# 0       NaN    NaN     NaN      U  12/29/2020  01/01/2021      3.0
# 1       NaN    NaN       Y      N  12/21/2020  12/22/2020      1.0
# 2       4.0    NaN     NaN      U  12/29/2020  12/29/2020      0.0
# 3       NaN    NaN     NaN      Y  12/28/2020  12/28/2020      0.0
# 4       NaN    NaN     NaN      U  12/22/2020  12/26/2020      4.0

# %% [markdown]
# #### 2021VAERSSymptoms.csv

# %%
# Import data file
VAERSsymptoms = "dataUsed/2021VAERSSYMPTOMS.csv"

# Read data file, need the encoding to read properly
vaer_symptoms_raw = pd.read_csv(VAERSsymptoms, encoding="ISO-8859-1")
display(vaer_symptoms_raw.head(2))
display(vaer_symptoms_raw.tail(2))
# Out:
#    VAERS_ID      SYMPTOM1  SYMPTOMVERSION1  \
# 0    916710  Appendicitis             23.1
# 1    916741        Chills             23.1
#
#                                SYMPTOM2  SYMPTOMVERSION2 SYMPTOM3  \
# 0  Band neutrophil percentage increased             23.1  Surgery
# 1        Complex regional pain syndrome             23.1  Fatigue
#
#    SYMPTOMVERSION3                          SYMPTOM4  SYMPTOMVERSION4  \
# 0             23.1  White blood cell count increased             23.1
# 1             23.1                          Headache             23.1
#
#                           SYMPTOM5  SYMPTOMVERSION5
# 0                              NaN              NaN
# 1  Joint range of motion decreased             23.1
#       VAERS_ID SYMPTOM1  SYMPTOMVERSION1   SYMPTOM2  SYMPTOMVERSION2 SYMPTOM3  \
# 4710    983919    Death             23.1        NaN              NaN      NaN
# 4711    985205    Death             23.1  Dizziness             23.1  Malaise
#
#       SYMPTOMVERSION3 SYMPTOM4  SYMPTOMVERSION4 SYMPTOM5  SYMPTOMVERSION5
# 4710              NaN      NaN              NaN      NaN              NaN
# 4711             23.1      NaN              NaN      NaN              NaN

# %%
# Extract the columns names
columns3 = list(vaer_symptoms_raw.columns)
columns3
# Out:
# ['VAERS_ID',
#  'SYMPTOM1',
#  'SYMPTOMVERSION1',
#  'SYMPTOM2',
#  'SYMPTOMVERSION2',
#  'SYMPTOM3',
#  'SYMPTOMVERSION3',
#  'SYMPTOM4',
#  'SYMPTOMVERSION4',
#  'SYMPTOM5',
#  'SYMPTOMVERSION5']

# %%
# Create a dataframe with the wanted columns only
wanted_columns3 = vaer_symptoms_raw[['VAERS_ID',
 'SYMPTOM1',
 'SYMPTOM2',
 'SYMPTOM3',
 'SYMPTOM4',
 'SYMPTOM5'
]]
wanted_columns3.tail(5)
# Out:
#       VAERS_ID                                  SYMPTOM1  \
# 4707    983721                                     Death
# 4708    983766                        Blood pH decreased
# 4709    983766  International normalised ratio increased
# 4710    983919                                     Death
# 4711    985205                                     Death
#
#                                                SYMPTOM2  \
# 4707                                                NaN
# 4708                              Cardiac failure acute
# 4709  N-terminal prohormone brain natriuretic peptid...
# 4710                                                NaN
# 4711                                          Dizziness
#
#                       SYMPTOM3 SYMPTOM4  SYMPTOM5
# 4707                       NaN      NaN       NaN
# 4708          Chest discomfort    Death  Dyspnoea
# 4709  SARS-CoV-2 test negative      NaN       NaN
# 4710                       NaN      NaN       NaN
# 4711                   Malaise      NaN       NaN

# %% [markdown]
# ### 2021 VAERS Datasets-Merging

# %%
# Merge the two organized dataframes
merge_2data = pd.merge(filtered_data,wanted_columns2, on="VAERS_ID", how="left")
display(merge_2data.head(2))
display(merge_2data.tail(2))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE STATE  AGE_YRS  \
# 0    916710  COVID19          MODERNA               1       LA    MO     23.0
# 1    916741  COVID19  PFIZER\BIONTECH               1       LA    AR     68.0
#
#   SEX DIED DATEDIED L_THREAT  ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE  \
# 0   F  NaN      NaN        Y       NaN        Y       NaN    NaN     NaN
# 1   F  NaN      NaN      NaN       NaN      NaN       NaN    NaN       Y
#
#   RECOVD    VAX_DATE  ONSET_DATE  NUMDAYS
# 0      U  12/29/2020  01/01/2021      3.0
# 1      N  12/21/2020  12/22/2020      1.0
#       VAERS_ID VAX_TYPE VAX_MANU VAX_DOSE_SERIES VAX_SITE STATE  AGE_YRS SEX  \
# 2842    983919  COVID19  MODERNA               1       LA    FL     69.0   M
# 2843    985205  COVID19  MODERNA               1       UN    OH     75.0   M
#
#      DIED    DATEDIED L_THREAT  ER_VISIT HOSPITAL  HOSPDAYS X_STAY DISABLE  \
# 2842    Y         NaN      NaN       NaN      NaN       NaN    NaN     NaN
# 2843    Y  01/26/2021      NaN       NaN      NaN       NaN    NaN     NaN
#
#      RECOVD    VAX_DATE  ONSET_DATE  NUMDAYS
# 2842    NaN  01/21/2021  01/01/2021      NaN
# 2843      N  01/25/2021  01/26/2021      1.0

# %%
# Merge all three organized dataframes
merge_all = pd.merge(merge_2data,wanted_columns3,on="VAERS_ID", how="left")
display(merge_all.head(4))
display(merge_all.tail(4))
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU VAX_DOSE_SERIES VAX_SITE STATE  AGE_YRS  \
# 0    916710  COVID19          MODERNA               1       LA    MO     23.0
# 1    916741  COVID19  PFIZER\BIONTECH               1       LA    AR     68.0
# 2    916741  COVID19  PFIZER\BIONTECH               1       LA    AR     68.0
# 3    916742  COVID19  PFIZER\BIONTECH               1      NaN    MN     29.0
#
#   SEX DIED DATEDIED  ... DISABLE  RECOVD    VAX_DATE  ONSET_DATE NUMDAYS  \
# 0   F  NaN      NaN  ...     NaN       U  12/29/2020  01/01/2021     3.0
# 1   F  NaN      NaN  ...       Y       N  12/21/2020  12/22/2020     1.0
# 2   F  NaN      NaN  ...       Y       N  12/21/2020  12/22/2020     1.0
# 3   F  NaN      NaN  ...     NaN       U  12/29/2020  12/29/2020     0.0
#
#                 SYMPTOM1                              SYMPTOM2  \
# 0           Appendicitis  Band neutrophil percentage increased
# 1                 Chills        Complex regional pain syndrome
# 2                Myalgia                     Pain in extremity
# 3  Anaphylactic reaction                            Blood test
#
#               SYMPTOM3                          SYMPTOM4  \
# 0              Surgery  White blood cell count increased
# 1              Fatigue                          Headache
# 2  Peripheral swelling                    X-ray abnormal
# 3    Burning sensation    Central venous catheterisation
#
#                           SYMPTOM5
# 0                              NaN
# 1  Joint range of motion decreased
# 2                              NaN
# 3                        Dysphonia
#
# [4 rows x 25 columns]
#       VAERS_ID VAX_TYPE VAX_MANU VAX_DOSE_SERIES VAX_SITE STATE  AGE_YRS SEX  \
# 4563    983766  COVID19  MODERNA               1       RA    NC     90.0   F
# 4564    983766  COVID19  MODERNA               1       RA    NC     90.0   F
# 4565    983919  COVID19  MODERNA               1       LA    FL     69.0   M
# 4566    985205  COVID19  MODERNA               1       UN    OH     75.0   M
#
#      DIED    DATEDIED  ... DISABLE  RECOVD    VAX_DATE  ONSET_DATE NUMDAYS  \
# 4563    Y  01/24/2021  ...     NaN       N  01/16/2021  01/21/2021     5.0
# 4564    Y  01/24/2021  ...     NaN       N  01/16/2021  01/21/2021     5.0
# 4565    Y         NaN  ...     NaN     NaN  01/21/2021  01/01/2021     NaN
# 4566    Y  01/26/2021  ...     NaN       N  01/25/2021  01/26/2021     1.0
#
#                                       SYMPTOM1  \
# 4563                        Blood pH decreased
# 4564  International normalised ratio increased
# 4565                                     Death
# 4566                                     Death
#
#                                                SYMPTOM2  \
# 4563                              Cardiac failure acute
# 4564  N-terminal prohormone brain natriuretic peptid...
# 4565                                                NaN
# 4566                                          Dizziness
#
#                       SYMPTOM3 SYMPTOM4  SYMPTOM5
# 4563          Chest discomfort    Death  Dyspnoea
# 4564  SARS-CoV-2 test negative      NaN       NaN
# 4565                       NaN      NaN       NaN
# 4566                   Malaise      NaN       NaN
#
# [4 rows x 25 columns]

# %% [markdown]
# ### World Wide Dataset-Data Cleaning

# %%
# Import data file
worldWideData = "dataUsed/WorldWideData.csv"

# Read data file, need the encoding to read properly
world_raw = pd.read_csv(worldWideData, encoding="ISO-8859-1")
display(world_raw.head(2))
display(world_raw.tail(2))
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
#
# [2 rows x 59 columns]
#       iso_code continent  location        date  total_cases  new_cases  \
# 67893      ZWE    Africa  Zimbabwe  2021-02-08      34658.0      106.0
# 67894      ZWE    Africa  Zimbabwe  2021-02-09      34781.0      123.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 67893             158.571        1339.0        13.0               15.000  ...
# 67894             138.143        1353.0        14.0               14.143  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 67893        1899.775             21.4                307.846
# 67894        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 67893                 1.82             1.6          30.7
# 67894                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 67893                  36.791                         1.7            61.49
# 67894                  36.791                         1.7            61.49
#
#        human_development_index
# 67893                    0.571
# 67894                    0.571
#
# [2 rows x 59 columns]

# %%
# Extract the columns names
columns4 = list(world_raw.columns)
columns4
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'new_vaccinations',
#  'new_vaccinations_smoothed',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'new_vaccinations_smoothed_per_million',
#  'stringency_index',
#  'population',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'female_smokers',
#  'male_smokers',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index']

# %%
# Create a dataframe with the wanted columns only
wanted_columns4 = world_raw[['iso_code',
 'continent',
 'location',
 'date',
 'total_cases',
 'new_cases' , 
 'total_deaths',
 'new_deaths',
 'total_tests',
 'positive_rate',
 'total_vaccinations',
 'people_vaccinated',
 'people_fully_vaccinated',
 'new_vaccinations',
 'population',
 'median_age',
 'aged_65_older',
 'aged_70_older'
]]
display(wanted_columns4.head(4))
display(wanted_columns4.tail(4))
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
#
#    total_deaths  new_deaths  total_tests  positive_rate  total_vaccinations  \
# 0           NaN         NaN          NaN            NaN                 NaN
# 1           NaN         NaN          NaN            NaN                 NaN
# 2           NaN         NaN          NaN            NaN                 NaN
# 3           NaN         NaN          NaN            NaN                 NaN
#
#    people_vaccinated  people_fully_vaccinated  new_vaccinations  population  \
# 0                NaN                      NaN               NaN  38928341.0
# 1                NaN                      NaN               NaN  38928341.0
# 2                NaN                      NaN               NaN  38928341.0
# 3                NaN                      NaN               NaN  38928341.0
#
#    median_age  aged_65_older  aged_70_older
# 0        18.6          2.581          1.337
# 1        18.6          2.581          1.337
# 2        18.6          2.581          1.337
# 3        18.6          2.581          1.337
#       iso_code continent  location        date  total_cases  new_cases  \
# 67891      ZWE    Africa  Zimbabwe  2021-02-06      34487.0      156.0
# 67892      ZWE    Africa  Zimbabwe  2021-02-07      34552.0       65.0
# 67893      ZWE    Africa  Zimbabwe  2021-02-08      34658.0      106.0
# 67894      ZWE    Africa  Zimbabwe  2021-02-09      34781.0      123.0
#
#        total_deaths  new_deaths  total_tests  positive_rate  \
# 67891        1316.0        13.0     335489.0          0.064
# 67892        1326.0        10.0     336553.0          0.064
# 67893        1339.0        13.0          NaN            NaN
# 67894        1353.0        14.0          NaN            NaN
#
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 67891                 NaN                NaN                      NaN
# 67892                 NaN                NaN                      NaN
# 67893                 NaN                NaN                      NaN
# 67894                 NaN                NaN                      NaN
#
#        new_vaccinations  population  median_age  aged_65_older  aged_70_older
# 67891               NaN  14862927.0        19.6          2.822          1.882
# 67892               NaN  14862927.0        19.6          2.822          1.882
# 67893               NaN  14862927.0        19.6          2.822          1.882
# 67894               NaN  14862927.0        19.6          2.822          1.882

# %%
# Get the date list
worldwidedate = wanted_columns4["date"]
worldwidedatelist = list(worldwidedate.unique())
worldwidedatelist
# Out:
# ['2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
#  '2020-02-28',
#  '2020-02-29',
#  '2020-03-01',
#  '2020-03-02',
#  '2020-03-03',
#  '2020-03-04',
#  '2020-03-05',
#  '2020-03-06',
#  '2020-03-07',
#  '2020-03-08',
#  '2020-03-09',
#  '2020-03-10',
#  '2020-03-11',
#  '2020-03-12',
#  '2020-03-13',
#  '2020-03-14',
#  '2020-03-15',
#  '2020-03-16',
#  '2020-03-17',
#  '2020-03-18',
#  '2020-03-19',
#  '2020-03-20',
#  '2020-03-21',
#  '2020-03-22',
#  '2020-03-23',
#  '2020-03-24',
#  '2020-03-25',
#  '2020-03-26',
#  '2020-03-27',
#  '2020-03-28',
#  '2020-03-29',
#  '2020-03-30',
#  '2020-03-31',
#  '2020-04-01',
#  '2020-04-02',
#  '2020-04-03',
#  '2020-04-04',
#  '2020-04-05',
#  '2020-04-06',
#  '2020-04-07',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-12',
#  '2020-04-13',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-16',
#  '2020-04-17',
#  '2020-04-18',
#  '2020-04-19',
#  '2020-04-20',
#  '2020-04-21',
#  '2020-04-22',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-04-25',
#  '2020-04-26',
#  '2020-04-27',
#  '2020-04-28',
#  '2020-04-29',
#  '2020-04-30',
#  '2020-05-01',
#  '2020-05-02',
#  '2020-05-03',
#  '2020-05-04',
#  '2020-05-05',
#  '2020-05-06',
#  '2020-05-07',
#  '2020-05-08',
#  '2020-05-09',
#  '2020-05-10',
#  '2020-05-11',
#  '2020-05-12',
#  '2020-05-13',
#  '2020-05-14',
#  '2020-05-15',
#  '2020-05-16',
#  '2020-05-17',
#  '2020-05-18',
#  '2020-05-19',
#  '2020-05-20',
#  '2020-05-21',
#  '2020-05-22',
#  '2020-05-23',
#  '2020-05-24',
#  '2020-05-25',
#  '2020-05-26',
#  '2020-05-27',
#  '2020-05-28',
#  '2020-05-29',
#  '2020-05-30',
#  '2020-05-31',
#  '2020-06-01',
#  '2020-06-02',
#  '2020-06-03',
#  '2020-06-04',
#  '2020-06-05',
#  '2020-06-06',
#  '2020-06-07',
#  '2020-06-08',
#  '2020-06-09',
#  '2020-06-10',
#  '2020-06-11',
#  '2020-06-12',
#  '2020-06-13',
#  '2020-06-14',
#  '2020-06-15',
#  '2020-06-16',
#  '2020-06-17',
#  '2020-06-18',
#  '2020-06-19',
#  '2020-06-20',
#  '2020-06-21',
#  '2020-06-22',
#  '2020-06-23',
#  '2020-06-24',
#  '2020-06-25',
#  '2020-06-26',
#  '2020-06-27',
#  '2020-06-28',
#  '2020-06-29',
#  '2020-06-30',
#  '2020-07-01',
#  '2020-07-02',
#  '2020-07-03',
#  '2020-07-04',
#  '2020-07-05',
#  '2020-07-06',
#  '2020-07-07',
#  '2020-07-08',
#  '2020-07-09',
#  '2020-07-10',
#  '2020-07-11',
#  '2020-07-12',
#  '2020-07-13',
#  '2020-07-14',
#  '2020-07-15',
#  '2020-07-16',
#  '2020-07-17',
#  '2020-07-18',
#  '2020-07-19',
#  '2020-07-20',
#  '2020-07-21',
#  '2020-07-22',
#  '2020-07-23',
#  '2020-07-24',
#  '2020-07-25',
#  '2020-07-26',
#  '2020-07-27',
#  '2020-07-28',
#  '2020-07-29',
#  '2020-07-30',
#  '2020-07-31',
#  '2020-08-01',
#  '2020-08-02',
#  '2020-08-03',
#  '2020-08-04',
#  '2020-08-05',
#  '2020-08-06',
#  '2020-08-07',
#  '2020-08-08',
#  '2020-08-09',
#  '2020-08-10',
#  '2020-08-11',
#  '2020-08-12',
#  '2020-08-13',
#  '2020-08-14',
#  '2020-08-15',
#  '2020-08-16',
#  '2020-08-17',
#  '2020-08-18',
#  '2020-08-19',
#  '2020-08-20',
#  '2020-08-21',
#  '2020-08-22',
#  '2020-08-23',
#  '2020-08-24',
#  '2020-08-25',
#  '2020-08-26',
#  '2020-08-27',
#  '2020-08-28',
#  '2020-08-29',
#  '2020-08-30',
#  '2020-08-31',
#  '2020-09-01',
#  '2020-09-02',
#  '2020-09-03',
#  '2020-09-04',
#  '2020-09-05',
#  '2020-09-06',
#  '2020-09-07',
#  '2020-09-08',
#  '2020-09-09',
#  '2020-09-10',
#  '2020-09-11',
#  '2020-09-12',
#  '2020-09-13',
#  '2020-09-14',
#  '2020-09-15',
#  '2020-09-16',
#  '2020-09-17',
#  '2020-09-18',
#  '2020-09-19',
#  '2020-09-20',
#  '2020-09-21',
#  '2020-09-22',
#  '2020-09-23',
#  '2020-09-24',
#  '2020-09-25',
#  '2020-09-26',
#  '2020-09-27',
#  '2020-09-28',
#  '2020-09-29',
#  '2020-09-30',
#  '2020-10-01',
#  '2020-10-02',
#  '2020-10-03',
#  '2020-10-04',
#  '2020-10-05',
#  '2020-10-06',
#  '2020-10-07',
#  '2020-10-08',
#  '2020-10-09',
#  '2020-10-10',
#  '2020-10-11',
#  '2020-10-12',
#  '2020-10-13',
#  '2020-10-14',
#  '2020-10-15',
#  '2020-10-16',
#  '2020-10-17',
#  '2020-10-18',
#  '2020-10-19',
#  '2020-10-20',
#  '2020-10-21',
#  '2020-10-22',
#  '2020-10-23',
#  '2020-10-24',
#  '2020-10-25',
#  '2020-10-26',
#  '2020-10-27',
#  '2020-10-28',
#  '2020-10-29',
#  '2020-10-30',
#  '2020-10-31',
#  '2020-11-01',
#  '2020-11-02',
#  '2020-11-03',
#  '2020-11-04',
#  '2020-11-05',
#  '2020-11-06',
#  '2020-11-07',
#  '2020-11-08',
#  '2020-11-09',
#  '2020-11-10',
#  '2020-11-11',
#  '2020-11-12',
#  '2020-11-13',
#  '2020-11-14',
#  '2020-11-15',
#  '2020-11-16',
#  '2020-11-17',
#  '2020-11-18',
#  '2020-11-19',
#  '2020-11-20',
#  '2020-11-21',
#  '2020-11-22',
#  '2020-11-23',
#  '2020-11-24',
#  '2020-11-25',
#  '2020-11-26',
#  '2020-11-27',
#  '2020-11-28',
#  '2020-11-29',
#  '2020-11-30',
#  '2020-12-01',
#  '2020-12-02',
#  '2020-12-03',
#  '2020-12-04',
#  '2020-12-05',
#  '2020-12-06',
#  '2020-12-07',
#  '2020-12-08',
#  '2020-12-09',
#  '2020-12-10',
#  '2020-12-11',
#  '2020-12-12',
#  '2020-12-13',
#  '2020-12-14',
#  '2020-12-15',
#  '2020-12-16',
#  '2020-12-17',
#  '2020-12-18',
#  '2020-12-19',
#  '2020-12-20',
#  '2020-12-21',
#  '2020-12-22',
#  '2020-12-23',
#  '2020-12-24',
#  '2020-12-25',
#  '2020-12-26',
#  '2020-12-27',
#  '2020-12-28',
#  '2020-12-29',
#  '2020-12-30',
#  '2020-12-31',
#  '2021-01-01',
#  '2021-01-02',
#  '2021-01-03',
#  '2021-01-04',
#  '2021-01-05',
#  '2021-01-06',
#  '2021-01-07',
#  '2021-01-08',
#  '2021-01-09',
#  '2021-01-10',
#  '2021-01-11',
#  '2021-01-12',
#  '2021-01-13',
#  '2021-01-14',
#  '2021-01-15',
#  '2021-01-16',
#  '2021-01-17',
#  '2021-01-18',
#  '2021-01-19',
#  '2021-01-20',
#  '2021-01-21',
#  '2021-01-22',
#  '2021-01-23',
#  '2021-01-24',
#  '2021-01-25',
#  '2021-01-26',
#  '2021-01-27',
#  '2021-01-28',
#  '2021-01-29',
#  '2021-01-30',
#  '2021-01-31',
#  '2021-02-01',
#  '2021-02-02',
#  '2021-02-03',
#  '2021-02-04',
#  '2021-02-05',
#  '2021-02-06',
#  '2021-02-07',
#  '2021-02-08',
#  '2021-02-09',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-18',
#  '2020-02-19',
#  '2020-02-20',
#  '2020-02-21',
#  '2020-02-22',
#  '2020-02-23',
#  '2020-01-01',
#  '2020-01-02',
#  '2020-01-03',
#  '2020-01-04',
#  '2020-01-05',
#  '2020-01-06',
#  '2020-01-07',
#  '2020-01-08',
#  '2020-01-09',
#  '2020-01-10',
#  '2020-01-11',
#  '2020-01-12',
#  '2020-01-13',
#  '2020-01-14',
#  '2020-01-15',
#  '2020-01-16',
#  '2020-01-17',
#  '2020-01-18',
#  '2020-01-19',
#  '2020-01-20',
#  '2020-01-21',
#  '2020-01-22',
#  '2020-01-23',
#  '2020-01-24',
#  '2020-01-25',
#  '2020-01-26',
#  '2020-01-27',
#  '2020-01-28',
#  '2020-01-29',
#  '2020-01-30',
#  '2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12']

# %%
# Get the dates when there is vaccination info
vaccination_info = wanted_columns4.dropna(how="any")
vaccination_info
# Out:
#       iso_code      continent        location        date  total_cases  \
# 2809       ARG  South America       Argentina  2021-01-21    1843077.0
# 2810       ARG  South America       Argentina  2021-01-22    1853830.0
# 2811       ARG  South America       Argentina  2021-01-23    1862192.0
# 2812       ARG  South America       Argentina  2021-01-24    1867223.0
# 2813       ARG  South America       Argentina  2021-01-25    1874801.0
# ...        ...            ...             ...         ...          ...
# 64338      GBR         Europe  United Kingdom  2021-02-01    3846851.0
# 64339      GBR         Europe  United Kingdom  2021-02-02    3863757.0
# 64340      GBR         Europe  United Kingdom  2021-02-03    3882972.0
# 64341      GBR         Europe  United Kingdom  2021-02-04    3903706.0
# 64716      USA  North America   United States  2021-01-25   25298986.0
#
#        new_cases  total_deaths  new_deaths  total_tests  positive_rate  \
# 2809     11396.0       46355.0       139.0    5017855.0          0.257
# 2810     10753.0       46575.0       220.0    5057091.0          0.258
# 2811      8362.0       46737.0       162.0    5085646.0          0.264
# 2812      5031.0       46827.0        90.0    5105622.0          0.260
# 2813      7578.0       47034.0       207.0    5144717.0          0.262
# ...          ...           ...         ...          ...            ...
# 64338    18668.0      106774.0       407.0   71011933.0          0.036
# 64339    16906.0      108225.0      1451.0   71642534.0          0.036
# 64340    19215.0      109547.0      1322.0   72464146.0          0.034
# 64341    20734.0      110462.0       915.0   73277874.0          0.032
# 64716   151095.0      422477.0      1946.0  291411859.0          0.097
#
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 2809             265724.0           249372.0                  16352.0
# 2810             279602.0           254456.0                  25146.0
# 2811             288064.0           258876.0                  29188.0
# 2812             292023.0           260036.0                  31987.0
# 2813             292386.0           260122.0                  32264.0
# ...                   ...                ...                      ...
# 64338          10143511.0          9646715.0                 496796.0
# 64339          10520433.0         10021471.0                 498962.0
# 64340          10992444.0         10490487.0                 501957.0
# 64341          11477040.0         10971047.0                 505993.0
# 64716          22734243.0         19252279.0                3346390.0
#
#        new_vaccinations   population  median_age  aged_65_older  aged_70_older
# 2809            17791.0   45195777.0        31.9         11.198          7.441
# 2810            13878.0   45195777.0        31.9         11.198          7.441
# 2811             8462.0   45195777.0        31.9         11.198          7.441
# 2812             3959.0   45195777.0        31.9         11.198          7.441
# 2813              363.0   45195777.0        31.9         11.198          7.441
# ...                 ...          ...         ...            ...            ...
# 64338          352935.0   67886004.0        40.8         18.517         12.527
# 64339          376922.0   67886004.0        40.8         18.517         12.527
# 64340          472011.0   67886004.0        40.8         18.517         12.527
# 64341          484596.0   67886004.0        40.8         18.517         12.527
# 64716          885588.0  331002647.0        38.3         15.413          9.732
#
# [402 rows x 18 columns]

# %%
# Get the date list
dorpnadate = vaccination_info["date"]
dorpnadatelist = list(dorpnadate.unique())
dorpnadatelist
# Out:
# ['2021-01-21',
#  '2021-01-22',
#  '2021-01-23',
#  '2021-01-24',
#  '2021-01-25',
#  '2021-01-26',
#  '2021-01-27',
#  '2021-01-28',
#  '2021-01-29',
#  '2021-01-30',
#  '2021-01-18',
#  '2021-01-19',
#  '2021-01-20',
#  '2021-01-31',
#  '2021-02-01',
#  '2021-02-02',
#  '2021-02-03',
#  '2021-02-04',
#  '2021-02-05',
#  '2021-02-06',
#  '2021-01-14',
#  '2021-01-15',
#  '2021-01-16',
#  '2021-01-17',
#  '2021-02-07',
#  '2021-01-04',
#  '2021-01-05',
#  '2021-01-06',
#  '2021-01-07',
#  '2021-01-08',
#  '2021-01-09',
#  '2021-01-10',
#  '2021-01-11',
#  '2021-01-12',
#  '2021-01-13']

# %%
# Turn into a dataframe for organization
dorpnadateDf = pd.DataFrame(dorpnadatelist)
dorpnadateDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       35 non-null     object
# dtypes: object(1)
# memory usage: 408.0+ bytes

# %%
# Convert to datetime type
dorpnadateDf[0]=dorpnadateDf[0].astype('datetime64[ns]')
dorpnadateDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       35 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 408.0 bytes

# %%
# Organize
dorpnadateorganized = dorpnadateDf.sort_values(by=0)
dorpnadateorganized.reset_index(drop=True, inplace=True)
dorpnadateorganized
# Out:
#             0
# 0  2021-01-04
# 1  2021-01-05
# 2  2021-01-06
# 3  2021-01-07
# 4  2021-01-08
# 5  2021-01-09
# 6  2021-01-10
# 7  2021-01-11
# 8  2021-01-12
# 9  2021-01-13
# 10 2021-01-14
# 11 2021-01-15
# 12 2021-01-16
# 13 2021-01-17
# 14 2021-01-18
# 15 2021-01-19
# 16 2021-01-20
# 17 2021-01-21
# 18 2021-01-22
# 19 2021-01-23
# 20 2021-01-24
# 21 2021-01-25
# 22 2021-01-26
# 23 2021-01-27
# 24 2021-01-28
# 25 2021-01-29
# 26 2021-01-30
# 27 2021-01-31
# 28 2021-02-01
# 29 2021-02-02
# 30 2021-02-03
# 31 2021-02-04
# 32 2021-02-05
# 33 2021-02-06
# 34 2021-02-07

# %%
# Remove unneeded dates
neededDates = dorpnadateorganized.drop(dorpnadateorganized.index[24:35])
neededDates.reset_index(drop=True, inplace=True)
neededDates
# Out:
#             0
# 0  2021-01-04
# 1  2021-01-05
# 2  2021-01-06
# 3  2021-01-07
# 4  2021-01-08
# 5  2021-01-09
# 6  2021-01-10
# 7  2021-01-11
# 8  2021-01-12
# 9  2021-01-13
# 10 2021-01-14
# 11 2021-01-15
# 12 2021-01-16
# 13 2021-01-17
# 14 2021-01-18
# 15 2021-01-19
# 16 2021-01-20
# 17 2021-01-21
# 18 2021-01-22
# 19 2021-01-23
# 20 2021-01-24
# 21 2021-01-25
# 22 2021-01-26
# 23 2021-01-27

# %% [markdown]
# #### Filter By US Data

# %%
# Pull out US data
us_info = wanted_columns4.loc[wanted_columns4["location"]=="United States"]
us_info.reset_index(drop=True, inplace=True)
us_info
# Out:
#     iso_code      continent       location        date  total_cases  \
# 0        USA  North America  United States  2020-01-22          1.0
# 1        USA  North America  United States  2020-01-23          1.0
# 2        USA  North America  United States  2020-01-24          2.0
# 3        USA  North America  United States  2020-01-25          2.0
# 4        USA  North America  United States  2020-01-26          5.0
# ..       ...            ...            ...         ...          ...
# 380      USA  North America  United States  2021-02-05   26813772.0
# 381      USA  North America  United States  2021-02-06   26917787.0
# 382      USA  North America  United States  2021-02-07   27007368.0
# 383      USA  North America  United States  2021-02-08   27097095.0
# 384      USA  North America  United States  2021-02-09   27192455.0
#
#      new_cases  total_deaths  new_deaths  total_tests  positive_rate  \
# 0          NaN           NaN         NaN          NaN            NaN
# 1          0.0           NaN         NaN          NaN            NaN
# 2          1.0           NaN         NaN          NaN            NaN
# 3          0.0           NaN         NaN          NaN            NaN
# 4          3.0           NaN         NaN          NaN            NaN
# ..         ...           ...         ...          ...            ...
# 380   133558.0      459555.0      3674.0          NaN            NaN
# 381   104015.0      462169.0      2614.0          NaN            NaN
# 382    89581.0      463476.0      1307.0          NaN            NaN
# 383    89727.0      465072.0      1596.0          NaN            NaN
# 384    95360.0      468203.0      3131.0          NaN            NaN
#
#      total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                   NaN                NaN                      NaN
# 1                   NaN                NaN                      NaN
# 2                   NaN                NaN                      NaN
# 3                   NaN                NaN                      NaN
# 4                   NaN                NaN                      NaN
# ..                  ...                ...                      ...
# 380          36819212.0         28909497.0                7503864.0
# 381          39037964.0         30250964.0                8317180.0
# 382          41210937.0         31579100.0                9147185.0
# 383          42417617.0         32340146.0                9518015.0
# 384          43206190.0         32867213.0                9840429.0
#
#      new_vaccinations   population  median_age  aged_65_older  aged_70_older
# 0                 NaN  331002647.0        38.3         15.413          9.732
# 1                 NaN  331002647.0        38.3         15.413          9.732
# 2                 NaN  331002647.0        38.3         15.413          9.732
# 3                 NaN  331002647.0        38.3         15.413          9.732
# 4                 NaN  331002647.0        38.3         15.413          9.732
# ..                ...          ...         ...            ...            ...
# 380         1615502.0  331002647.0        38.3         15.413          9.732
# 381         2218752.0  331002647.0        38.3         15.413          9.732
# 382         2172973.0  331002647.0        38.3         15.413          9.732
# 383         1206680.0  331002647.0        38.3         15.413          9.732
# 384          788573.0  331002647.0        38.3         15.413          9.732
#
# [385 rows x 18 columns]

# %%
us_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   iso_code                 385 non-null    object
#  1   continent                385 non-null    object
#  2   location                 385 non-null    object
#  3   date                     385 non-null    object
#  4   total_cases              385 non-null    float64
#  5   new_cases                384 non-null    float64
#  6   total_deaths             347 non-null    float64
#  7   new_deaths               347 non-null    float64
#  8   total_tests              339 non-null    float64
#  9   positive_rate            48 non-null     float64
#  10  total_vaccinations       39 non-null     float64
#  11  people_vaccinated        38 non-null     float64
#  12  people_fully_vaccinated  24 non-null     float64
#  13  new_vaccinations         30 non-null     float64
#  14  population               385 non-null    float64
#  15  median_age               385 non-null    float64
#  16  aged_65_older            385 non-null    float64
#  17  aged_70_older            385 non-null    float64
# dtypes: float64(14), object(4)
# memory usage: 54.3+ KB

# %%
# Create a Converted Data column
us_info_copy = us_info.copy()
us_info_covert = us_info["date"].astype('datetime64[ns]')
us_info_copy["CONVERTED_DATE"] = us_info_covert
us_info_copy
# Out:
#     iso_code      continent       location        date  total_cases  \
# 0        USA  North America  United States  2020-01-22          1.0
# 1        USA  North America  United States  2020-01-23          1.0
# 2        USA  North America  United States  2020-01-24          2.0
# 3        USA  North America  United States  2020-01-25          2.0
# 4        USA  North America  United States  2020-01-26          5.0
# ..       ...            ...            ...         ...          ...
# 380      USA  North America  United States  2021-02-05   26813772.0
# 381      USA  North America  United States  2021-02-06   26917787.0
# 382      USA  North America  United States  2021-02-07   27007368.0
# 383      USA  North America  United States  2021-02-08   27097095.0
# 384      USA  North America  United States  2021-02-09   27192455.0
#
#      new_cases  total_deaths  new_deaths  total_tests  positive_rate  \
# 0          NaN           NaN         NaN          NaN            NaN
# 1          0.0           NaN         NaN          NaN            NaN
# 2          1.0           NaN         NaN          NaN            NaN
# 3          0.0           NaN         NaN          NaN            NaN
# 4          3.0           NaN         NaN          NaN            NaN
# ..         ...           ...         ...          ...            ...
# 380   133558.0      459555.0      3674.0          NaN            NaN
# 381   104015.0      462169.0      2614.0          NaN            NaN
# 382    89581.0      463476.0      1307.0          NaN            NaN
# 383    89727.0      465072.0      1596.0          NaN            NaN
# 384    95360.0      468203.0      3131.0          NaN            NaN
#
#      total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                   NaN                NaN                      NaN
# 1                   NaN                NaN                      NaN
# 2                   NaN                NaN                      NaN
# 3                   NaN                NaN                      NaN
# 4                   NaN                NaN                      NaN
# ..                  ...                ...                      ...
# 380          36819212.0         28909497.0                7503864.0
# 381          39037964.0         30250964.0                8317180.0
# 382          41210937.0         31579100.0                9147185.0
# 383          42417617.0         32340146.0                9518015.0
# 384          43206190.0         32867213.0                9840429.0
#
#      new_vaccinations   population  median_age  aged_65_older  aged_70_older  \
# 0                 NaN  331002647.0        38.3         15.413          9.732
# 1                 NaN  331002647.0        38.3         15.413          9.732
# 2                 NaN  331002647.0        38.3         15.413          9.732
# 3                 NaN  331002647.0        38.3         15.413          9.732
# 4                 NaN  331002647.0        38.3         15.413          9.732
# ..                ...          ...         ...            ...            ...
# 380         1615502.0  331002647.0        38.3         15.413          9.732
# 381         2218752.0  331002647.0        38.3         15.413          9.732
# 382         2172973.0  331002647.0        38.3         15.413          9.732
# 383         1206680.0  331002647.0        38.3         15.413          9.732
# 384          788573.0  331002647.0        38.3         15.413          9.732
#
#     CONVERTED_DATE
# 0       2020-01-22
# 1       2020-01-23
# 2       2020-01-24
# 3       2020-01-25
# 4       2020-01-26
# ..             ...
# 380     2021-02-05
# 381     2021-02-06
# 382     2021-02-07
# 383     2021-02-08
# 384     2021-02-09
#
# [385 rows x 19 columns]

# %%
# Create a desired date list
date_list = list(neededDates[0])
date_list
# Out:
# [Timestamp('2021-01-04 00:00:00'),
#  Timestamp('2021-01-05 00:00:00'),
#  Timestamp('2021-01-06 00:00:00'),
#  Timestamp('2021-01-07 00:00:00'),
#  Timestamp('2021-01-08 00:00:00'),
#  Timestamp('2021-01-09 00:00:00'),
#  Timestamp('2021-01-10 00:00:00'),
#  Timestamp('2021-01-11 00:00:00'),
#  Timestamp('2021-01-12 00:00:00'),
#  Timestamp('2021-01-13 00:00:00'),
#  Timestamp('2021-01-14 00:00:00'),
#  Timestamp('2021-01-15 00:00:00'),
#  Timestamp('2021-01-16 00:00:00'),
#  Timestamp('2021-01-17 00:00:00'),
#  Timestamp('2021-01-18 00:00:00'),
#  Timestamp('2021-01-19 00:00:00'),
#  Timestamp('2021-01-20 00:00:00'),
#  Timestamp('2021-01-21 00:00:00'),
#  Timestamp('2021-01-22 00:00:00'),
#  Timestamp('2021-01-23 00:00:00'),
#  Timestamp('2021-01-24 00:00:00'),
#  Timestamp('2021-01-25 00:00:00'),
#  Timestamp('2021-01-26 00:00:00'),
#  Timestamp('2021-01-27 00:00:00')]

# %%
# Filter out the content based on the content of date list
us_info_filter = us_info_copy[us_info_copy.CONVERTED_DATE.isin(date_list)]
us_info_filter.reset_index(drop=True, inplace=True)
us_info_filter
# Out:
#    iso_code      continent       location        date  total_cases  new_cases  \
# 0       USA  North America  United States  2021-01-04   20906021.0   183790.0
# 1       USA  North America  United States  2021-01-05   21139547.0   233526.0
# 2       USA  North America  United States  2021-01-06   21393464.0   253917.0
# 3       USA  North America  United States  2021-01-07   21670202.0   276738.0
# 4       USA  North America  United States  2021-01-08   21962246.0   292044.0
# 5       USA  North America  United States  2021-01-09   22224220.0   261974.0
# 6       USA  North America  United States  2021-01-10   22437501.0   213281.0
# 7       USA  North America  United States  2021-01-11   22651464.0   213963.0
# 8       USA  North America  United States  2021-01-12   22877702.0   226238.0
# 9       USA  North America  United States  2021-01-13   23107573.0   229871.0
# 10      USA  North America  United States  2021-01-14   23342548.0   234975.0
# 11      USA  North America  United States  2021-01-15   23583255.0   240707.0
# 12      USA  North America  United States  2021-01-16   23784019.0   200764.0
# 13      USA  North America  United States  2021-01-17   23961423.0   177404.0
# 14      USA  North America  United States  2021-01-18   24104028.0   142605.0
# 15      USA  North America  United States  2021-01-19   24281012.0   176984.0
# 16      USA  North America  United States  2021-01-20   24463591.0   182579.0
# 17      USA  North America  United States  2021-01-21   24656646.0   193055.0
# 18      USA  North America  United States  2021-01-22   24846678.0   190032.0
# 19      USA  North America  United States  2021-01-23   25016816.0   170138.0
# 20      USA  North America  United States  2021-01-24   25147891.0   131075.0
# 21      USA  North America  United States  2021-01-25   25298986.0   151095.0
# 22      USA  North America  United States  2021-01-26   25445583.0   146597.0
# 23      USA  North America  United States  2021-01-27   25598061.0   152478.0
#
#     total_deaths  new_deaths  total_tests  positive_rate  total_vaccinations  \
# 0       354873.0      2066.0  256512858.0          0.146           4563260.0
# 1       358539.0      3666.0  258344484.0            NaN           4836469.0
# 2       362432.0      3893.0  260522788.0            NaN           5306797.0
# 3       366377.0      3945.0  262643869.0            NaN           5919418.0
# 4       370408.0      4031.0  264672008.0            NaN           6688231.0
# 5       373653.0      3245.0  266312503.0            NaN                 NaN
# 6       375516.0      1863.0  267422755.0            NaN                 NaN
# 7       377561.0      2045.0  268850460.0          0.120           8987322.0
# 8       381993.0      4432.0  270739758.0            NaN           9327138.0
# 9       385961.0      3968.0  272697680.0            NaN          10278462.0
# 10      389918.0      3957.0  274652647.0            NaN          11148991.0
# 11      393744.0      3826.0  276560542.0            NaN          12279180.0
# 12      397124.0      3380.0  278063103.0            NaN                 NaN
# 13      398920.0      1796.0  279091675.0            NaN                 NaN
# 14      400363.0      1443.0  280288680.0          0.112                 NaN
# 15      403061.0      2698.0  281993534.0            NaN          15707588.0
# 16      407441.0      4380.0  284030825.0            NaN          16525281.0
# 17      411631.0      4190.0  285989826.0            NaN          17546374.0
# 18      415408.0      3777.0  287836527.0            NaN          19107959.0
# 19      418733.0      3325.0  289313942.0            NaN          20537990.0
# 20      420531.0      1798.0  290276257.0            NaN          21848655.0
# 21      422477.0      1946.0  291411859.0          0.097          22734243.0
# 22      426532.0      4055.0  292970045.0            NaN          23540994.0
# 23      430487.0      3955.0  294606905.0            NaN          24652634.0
#
#     people_vaccinated  people_fully_vaccinated  new_vaccinations   population  \
# 0           4563260.0                      NaN               NaN  331002647.0
# 1           4836469.0                      NaN          273209.0  331002647.0
# 2           5306797.0                      NaN          470328.0  331002647.0
# 3           5919418.0                      NaN          612621.0  331002647.0
# 4           6688231.0                      NaN          768813.0  331002647.0
# 5                 NaN                      NaN               NaN  331002647.0
# 6                 NaN                      NaN               NaN  331002647.0
# 7           8987322.0                      NaN               NaN  331002647.0
# 8           9327138.0                      NaN          339816.0  331002647.0
# 9                 NaN                      NaN          951324.0  331002647.0
# 10          9690757.0                1342086.0          870529.0  331002647.0
# 11         10595866.0                1610524.0         1130189.0  331002647.0
# 12                NaN                      NaN               NaN  331002647.0
# 13                NaN                      NaN               NaN  331002647.0
# 14                NaN                      NaN               NaN  331002647.0
# 15         13595803.0                2023124.0               NaN  331002647.0
# 16         14270441.0                2161419.0          817693.0  331002647.0
# 17         15053257.0                2394961.0         1021093.0  331002647.0
# 18         16243093.0                2756953.0         1561585.0  331002647.0
# 19         17390345.0                3027865.0         1430031.0  331002647.0
# 20         18502131.0                3216836.0         1310665.0  331002647.0
# 21         19252279.0                3346390.0          885588.0  331002647.0
# 22         19902237.0                3481921.0          806751.0  331002647.0
# 23         20687970.0                3801053.0         1111640.0  331002647.0
#
#     median_age  aged_65_older  aged_70_older CONVERTED_DATE
# 0         38.3         15.413          9.732     2021-01-04
# 1         38.3         15.413          9.732     2021-01-05
# 2         38.3         15.413          9.732     2021-01-06
# 3         38.3         15.413          9.732     2021-01-07
# 4         38.3         15.413          9.732     2021-01-08
# 5         38.3         15.413          9.732     2021-01-09
# 6         38.3         15.413          9.732     2021-01-10
# 7         38.3         15.413          9.732     2021-01-11
# 8         38.3         15.413          9.732     2021-01-12
# 9         38.3         15.413          9.732     2021-01-13
# 10        38.3         15.413          9.732     2021-01-14
# 11        38.3         15.413          9.732     2021-01-15
# 12        38.3         15.413          9.732     2021-01-16
# 13        38.3         15.413          9.732     2021-01-17
# 14        38.3         15.413          9.732     2021-01-18
# 15        38.3         15.413          9.732     2021-01-19
# 16        38.3         15.413          9.732     2021-01-20
# 17        38.3         15.413          9.732     2021-01-21
# 18        38.3         15.413          9.732     2021-01-22
# 19        38.3         15.413          9.732     2021-01-23
# 20        38.3         15.413          9.732     2021-01-24
# 21        38.3         15.413          9.732     2021-01-25
# 22        38.3         15.413          9.732     2021-01-26
# 23        38.3         15.413          9.732     2021-01-27

# %% [markdown]
# ### Export Cleaned Datasets to SQLite

# %%
## Create the connection using the imported create_engine function and then invoking the connect method on it
engine = create_engine('sqlite:///VAERS.db', echo=False)
sqlite_connection = engine.connect()

# %%
## Set a variable name with the string of a table name
sqlite_vaers = "2021VAERS"
merge_all.to_sql(sqlite_vaers, sqlite_connection, if_exists='fail')

# %%
## Close the database connection 
sqlite_connection.close()

# %%
## Create the connection using the imported create_engine function and then invoking the connect method on it
engine = create_engine('sqlite:///worldWideData.db', echo=False)
sqlite_connection = engine.connect()

# %%
## Set a variable name with the string of a table name
sqlite_worldWideData = "worldWideData"
wanted_columns4.to_sql(sqlite_worldWideData, sqlite_connection, if_exists='fail')

# %%
## Close the database connection 
sqlite_connection.close()
